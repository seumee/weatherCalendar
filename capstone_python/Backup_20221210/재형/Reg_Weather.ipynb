# %%
import requests
import pprint
from bs4 import BeautifulSoup
from datetime import date

today = str(date.today()).replace('-', '')
today
service_key = '6znZJmoOWn11XV5XVvywRI7OWuzDd05lnbShgflZsJz7AyhsHL8HWioSL4Vu24dpjwTuPACqWjgAFHR3f9Gbdg%3D%3D'
params = f'&numOfRows=100&pageNo=1&dataType=JSON&regId=11D20000&tmFc={today}0600'
open_api = 'http://apis.data.go.kr/1360000/MidFcstInfoService/getMidLandFcst?serviceKey=' + service_key + params

res = requests.get(open_api)

if res.status_code == 200:
    data = res.json()
    pprint.pprint(data)
else:
    print("Error Code", res.status_code)
data
# Out:
# {'response': {'header': {'resultCode': '03', 'resultMsg': 'NO_DATA'}}}
# {'response': {'header': {'resultCode': '03', 'resultMsg': 'NO_DATA'}}}

# %%
import pandas as pd

weather = data['response']['body']['items']['item']
dic = {}
time = []
howisweatherlike = []
for key, value in weather[0].items():
    time.append(key)
    howisweatherlike.append(value)
for i in range(len(time)):
    dic[time[i]] = howisweatherlike[i]
print(dic['regId'])
# Out:
# 11D20000

# %%
weather = data['response']['body']['items']['item']
weather
# Out:
# [{'regId': '11D20000',
#   'rnSt3Am': 0,
#   'rnSt3Pm': 0,
#   'rnSt4Am': 30,
#   'rnSt4Pm': 0,
#   'rnSt5Am': 0,
#   'rnSt5Pm': 0,
#   'rnSt6Am': 20,
#   'rnSt6Pm': 30,
#   'rnSt7Am': 20,
#   'rnSt7Pm': 10,
#   'rnSt8': 20,
#   'rnSt9': 20,
#   'rnSt10': 10,
#   'wf3Am': '맑음',
#   'wf3Pm': '맑음',
#   'wf4Am': '구름많음',
#   'wf4Pm': '맑음',
#   'wf5Am': '맑음',
#   'wf5Pm': '맑음',
#   'wf6Am': '구름많음',
#   'wf6Pm': '구름많음',
#   'wf7Am': '맑음',
#   'wf7Pm': '맑음',
#   'wf8': '맑음',
#   'wf9': '맑음',
#   'wf10': '맑음'}]

# %%
import requests
import pprint
import pandas as pd
import openpyxl

def Weather():
    Reg = ['11B00000', '11D10000', '11D20000', '11C20000', '11C10000','11F20000','11F10000','11H10000','11H20000','11G00000']
    service_key = '6znZJmoOWn11XV5XVvywRI7OWuzDd05lnbShgflZsJz7AyhsHL8HWioSL4Vu24dpjwTuPACqWjgAFHR3f9Gbdg%3D%3D'
    time = []
    howisweatherlike = []
    dic = {}
    for Reg_code in Reg:
        params = f'&numOfRows=100&pageNo=1&dataType=JSON&regId={Reg_code}&tmFc={today}0600'
        open_api = 'http://apis.data.go.kr/1360000/MidFcstInfoService/getMidLandFcst?serviceKey=' + service_key + params
        res = requests.get(open_api)
        if res.status_code == 200:
            
            data = res.json()
            
        else:
            print("Error Code", res.status_code)
        weather = data['response']['body']['items']['item']
        for key, value in weather[0].items():
            time.append(key)
            howisweatherlike.append(value)
    
   
    return howisweatherlike
Weather()
# Out:
# ['11B00000',
#  30,
#  30,
#  0,
#  0,
#  0,
#  10,
#  30,
#  40,
#  20,
#  20,
#  10,
#  10,
#  10,
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '흐림',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11D10000',
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  30,
#  30,
#  20,
#  20,
#  10,
#  10,
#  20,
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11D20000',
#  0,
#  0,
#  30,
#  0,
#  0,
#  0,
#  20,
#  30,
#  20,
#  10,
#  20,
#  20,
#  10,
#  '맑음',
#  '맑음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11C20000',
#  40,
#  30,
#  30,
#  0,
#  10,
#  10,
#  30,
#  40,
#  40,
#  20,
#  10,
#  20,
#  20,
#  '흐림',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '흐림',
#  '흐림',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11C10000',
#  40,
#  30,
#  30,
#  0,
#  10,
#  10,
#  30,
#  40,
#  40,
#  20,
#  10,
#  10,
# ...

# %%
Reg = ['11B00000', '11D10000', '11D20000', '11C20000', '11C10000','11F20000','11F10000','11H10000','11H20000','11G00000']
service_key = '6znZJmoOWn11XV5XVvywRI7OWuzDd05lnbShgflZsJz7AyhsHL8HWioSL4Vu24dpjwTuPACqWjgAFHR3f9Gbdg%3D%3D'
time = []
howisweatherlike = []
dic = {}
for Reg_code in Reg:
    
    params = f'&numOfRows=100&pageNo=1&dataType=JSON&regId={Reg_code}&tmFc={today}0600'
    open_api = 'http://apis.data.go.kr/1360000/MidFcstInfoService/getMidLandFcst?serviceKey=' + service_key + params
    weather = data['response']['body']['items']['item']
    res = requests.get(open_api)
    if res.status_code == 200:
        
        data = res.json()
        
    else:
        print("Error Code", res.status_code)
    for key, value in weather[0].items():
        time.append(key)
        howisweatherlike.append(value)
    for i in range(len(time)):
        dic[time[i]] = howisweatherlike[i]
        df = pd.DataFrame.from_records([dic])
    
    
time
# Out:
# ['regId',
#  'rnSt3Am',
#  'rnSt3Pm',
#  'rnSt4Am',
#  'rnSt4Pm',
#  'rnSt5Am',
#  'rnSt5Pm',
#  'rnSt6Am',
#  'rnSt6Pm',
#  'rnSt7Am',
#  'rnSt7Pm',
#  'rnSt8',
#  'rnSt9',
#  'rnSt10',
#  'wf3Am',
#  'wf3Pm',
#  'wf4Am',
#  'wf4Pm',
#  'wf5Am',
#  'wf5Pm',
#  'wf6Am',
#  'wf6Pm',
#  'wf7Am',
#  'wf7Pm',
#  'wf8',
#  'wf9',
#  'wf10',
#  'regId',
#  'rnSt3Am',
#  'rnSt3Pm',
#  'rnSt4Am',
#  'rnSt4Pm',
#  'rnSt5Am',
#  'rnSt5Pm',
#  'rnSt6Am',
#  'rnSt6Pm',
#  'rnSt7Am',
#  'rnSt7Pm',
#  'rnSt8',
#  'rnSt9',
#  'rnSt10',
#  'wf3Am',
#  'wf3Pm',
#  'wf4Am',
#  'wf4Pm',
#  'wf5Am',
#  'wf5Pm',
#  'wf6Am',
#  'wf6Pm',
#  'wf7Am',
#  'wf7Pm',
#  'wf8',
#  'wf9',
#  'wf10',
#  'regId',
#  'rnSt3Am',
#  'rnSt3Pm',
#  'rnSt4Am',
#  'rnSt4Pm',
#  'rnSt5Am',
#  'rnSt5Pm',
#  'rnSt6Am',
#  'rnSt6Pm',
#  'rnSt7Am',
#  'rnSt7Pm',
#  'rnSt8',
#  'rnSt9',
#  'rnSt10',
#  'wf3Am',
#  'wf3Pm',
#  'wf4Am',
#  'wf4Pm',
#  'wf5Am',
#  'wf5Pm',
#  'wf6Am',
#  'wf6Pm',
#  'wf7Am',
#  'wf7Pm',
#  'wf8',
# ...

# %%
import openpyxl
from datetime import date
def Weather():
        
        excel_file = openpyxl.Workbook()
        excel_sheet = excel_file.active

        Reg = ['11B00000', '11D10000', '11D20000', '11C20000', '11C10000','11F20000','11F10000','11H10000','11H20000','11G00000']
        service_key = '6znZJmoOWn11XV5XVvywRI7OWuzDd05lnbShgflZsJz7AyhsHL8HWioSL4Vu24dpjwTuPACqWjgAFHR3f9Gbdg%3D%3D'
        time = []
        howisweatherlike = []
        dic = {}
        today = str(date.today()).replace('-', '')
        for Reg_code in Reg:
        
                params = f'&numOfRows=100&pageNo=1&dataType=JSON&regId={Reg_code}&tmFc={today}0600'
                open_api = 'http://apis.data.go.kr/1360000/MidFcstInfoService/getMidLandFcst?serviceKey=' + service_key + params
                res = requests.get(open_api)
                if res.status_code == 200:
                        
                        data = res.json()

                else:
                        print("Error Code", res.status_code)
        
                weather = data['response']['body']['items']['item']
                for key, value in weather[0].items():
                        time.append(key)
                        howisweatherlike.append(value)
        excel_sheet.append(['지역코드', '3일 후 오전 강수 확률', '3일후 오후 강수 확률', '4일 후 오전 강수 확률', '4일후 오후 강수 확률','5일 후 오전 강수 확률', '5일후 오후 강수 확률','6일 후 오전 강수 확률', '6일후 오후 강수 확률','7일 후 오전 강수 확률', '7일후 오후 강수 확률','8일 후 강수 확률', '9일후 강수 확률','10일 후 강수 확률', '3일후 오전 날씨예보', '3일후 오후 날씨예보', '4일후 오전 날씨예보', '4일후 오후 날씨예보', '5일후 오전 날씨예보', '5일후 오후 날씨예보', '6일후 오전 날씨예보', '6일후 오후 날씨예보', '7일후 오전 날씨예보', '7일후 오후 날씨예보', '8일후 날씨예보', '9일후 날씨예보', '10일 후 날씨예보'])
        for i in range(10):
                excel_sheet.append(howisweatherlike[i*27: (i+1)*27])
        
        excel_file.save('Con_Weather.xlsx')
        return howisweatherlike

# %%
Weather()
# Out:
# ['11B00000',
#  30,
#  30,
#  0,
#  0,
#  0,
#  10,
#  30,
#  40,
#  20,
#  20,
#  10,
#  10,
#  10,
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '흐림',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11D10000',
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  30,
#  30,
#  20,
#  20,
#  10,
#  10,
#  20,
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11D20000',
#  0,
#  0,
#  30,
#  0,
#  0,
#  0,
#  20,
#  30,
#  20,
#  10,
#  20,
#  20,
#  10,
#  '맑음',
#  '맑음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11C20000',
#  40,
#  30,
#  30,
#  0,
#  10,
#  10,
#  30,
#  40,
#  40,
#  20,
#  10,
#  20,
#  20,
#  '흐림',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '흐림',
#  '흐림',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11C10000',
#  40,
#  30,
#  30,
#  0,
#  10,
#  10,
#  30,
#  40,
#  40,
#  20,
#  10,
#  10,
# ...

# %%
print(time[0:27], howisweatherlike[0:27])
# Out:
# ['regId', 'rnSt3Am', 'rnSt3Pm', 'rnSt4Am', 'rnSt4Pm', 'rnSt5Am', 'rnSt5Pm', 'rnSt6Am', 'rnSt6Pm', 'rnSt7Am', 'rnSt7Pm', 'rnSt8', 'rnSt9', 'rnSt10', 'wf3Am', 'wf3Pm', 'wf4Am', 'wf4Pm', 'wf5Am', 'wf5Pm', 'wf6Am', 'wf6Pm', 'wf7Am', 'wf7Pm', 'wf8', 'wf9', 'wf10'] ['11D20000', 0, 0, 30, 0, 0, 0, 20, 30, 20, 10, 20, 20, 10, '맑음', '맑음', '구름많음', '맑음', '맑음', '맑음', '구름많음', '구름많음', '맑음', '맑음', '맑음', '맑음', '맑음']

# %% [markdown]
# ## 함수 말고 그냥 엑셀 저장한거

# %%
import openpyxl
from datetime import date

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active

Reg = ['11B00000', '11D10000', '11D20000', '11C20000', '11C10000','11F20000','11F10000','11H10000','11H20000','11G00000']
today = str(date.today()).replace('-','')
service_key = '6znZJmoOWn11XV5XVvywRI7OWuzDd05lnbShgflZsJz7AyhsHL8HWioSL4Vu24dpjwTuPACqWjgAFHR3f9Gbdg%3D%3D'
time = []
howisweatherlike = []
dic = {}
for Reg_code in Reg:
        
        params = f'&numOfRows=100&pageNo=1&dataType=JSON&regId={Reg_code}&tmFc={today}0600'
        open_api = 'http://apis.data.go.kr/1360000/MidFcstInfoService/getMidLandFcst?serviceKey=' + service_key + params
        res = requests.get(open_api)
        if res.status_code == 200:
            
                data = res.json()
            
        else:
                print("Error Code", res.status_code)
        
        weather = data['response']['body']['items']['item']
        for key, value in weather[0].items():
                time.append(key)
                howisweatherlike.append(value)
excel_sheet.append(['지역코드', '3일 후 오전 강수 확률', '3일후 오후 강수 확률', '4일 후 오전 강수 확률', '4일후 오후 강수 확률','5일 후 오전 강수 확률', '5일후 오후 강수 확률','6일 후 오전 강수 확률', '6일후 오후 강수 확률','7일 후 오전 강수 확률', '7일후 오후 강수 확률','8일 후 강수 확률', '9일후 강수 확률','10일 후 강수 확률', '3일후 오전 날씨예보', '3일후 오후 날씨예보', '4일후 오전 날씨예보', '4일후 오후 날씨예보', '5일후 오전 날씨예보', '5일후 오후 날씨예보', '6일후 오전 날씨예보', '6일후 오후 날씨예보', '7일후 오전 날씨예보', '7일후 오후 날씨예보', '8일후 날씨예보', '9일후 날씨예보', '10일 후 날씨예보'])
for i in range(10):
        excel_sheet.append(howisweatherlike[i*27: (i+1)*27])
excel_file.save('Con_Weather.xlsx')
howisweatherlike
# Out:
# ['11B00000',
#  30,
#  30,
#  0,
#  0,
#  0,
#  10,
#  30,
#  40,
#  20,
#  20,
#  10,
#  10,
#  10,
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '흐림',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11D10000',
#  0,
#  0,
#  0,
#  0,
#  0,
#  10,
#  30,
#  30,
#  20,
#  20,
#  10,
#  10,
#  20,
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11D20000',
#  0,
#  0,
#  30,
#  0,
#  0,
#  0,
#  20,
#  30,
#  20,
#  10,
#  20,
#  20,
#  10,
#  '맑음',
#  '맑음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11C20000',
#  40,
#  30,
#  30,
#  0,
#  10,
#  10,
#  30,
#  40,
#  40,
#  20,
#  10,
#  20,
#  20,
#  '흐림',
#  '구름많음',
#  '구름많음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '구름많음',
#  '흐림',
#  '흐림',
#  '맑음',
#  '맑음',
#  '맑음',
#  '맑음',
#  '11C10000',
#  40,
#  30,
#  30,
#  0,
#  10,
#  10,
#  30,
#  40,
#  40,
#  20,
#  10,
#  10,
# ...

# %%
from datetime import date
today = str(date.today()).replace('-', '')
today
# Out:
# '20221201'

# %%
from geopy.geocoders import Nominatim

geo_local = Nominatim(user_agent = 'South Korea')
reg = '용인시 처인구 역북동 명지로 116'
def geocoding(address):
    
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y
    
    except :
        return [0,0]
lon = geocoding(reg)[1]
lat = geocoding(reg)[0]
print(reg)
print(lat, lon)
# Out:
# 용인시 처인구 역북동 명지로 116
# 37.2309836 127.1881504
