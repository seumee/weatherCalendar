# %%
import pymysql
from sshtunnel import SSHTunnelForwarder
from geopy.geocoders import Nominatim

geo_local = Nominatim(user_agent = 'South Korea')
reg = '용인시 처인구 역북동 명지로 116'
def geocoding(address):
    
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y
    
    except :
        return [0,0]
lon = geocoding(reg)[1]
lat = geocoding(reg)[0]
"""
if __name__ == '__main__':
    with SSHTunnelForwarder(('seumchae.iptime.org', 8022),
                            ssh_username='capstone',
                            ssh_password='capstone2022',
                            remote_bind_address=('127.0.0.1', 3306)) as tunnel:
        with pymysql.connect(host='127.0.0.1', user='root', password='capstone2022', port=tunnel.local_bind_port,
                             db='Capstone', charset="utf8", cursorclass=pymysql.cursors.DictCursor) as conn:
            with conn.cursor() as cur:
                sql = f""""insert into client value ('이재성', 'zxcv@naver.com', '2580', {lon}, {lat}, 'kakao', 'abe3')""""  ## 예시
                cur.execute(sql)
                sql = 'select * from client;'
                cur.execute(sql)
                results = cur.fetchall()
                for result in results:
                    print(result)
    print('\nfinish!\n', '-----' * 20)
    print(reg)
    print(lat, lon)
"""
# Out:
# '\nif __name__ == \'__main__\':\n    with SSHTunnelForwarder((\'seumchae.iptime.org\', 8022),\n                            ssh_username=\'capstone\',\n                            ssh_password=\'capstone2022\',\n                            remote_bind_address=(\'127.0.0.1\', 3306)) as tunnel:\n        with pymysql.connect(host=\'127.0.0.1\', user=\'root\', password=\'capstone2022\', port=tunnel.local_bind_port,\n                             db=\'Capstone\', charset="utf8", cursorclass=pymysql.cursors.DictCursor) as conn:\n            with conn.cursor() as cur:\n                sql = finsert into client value (\'이재성\', \'zxcv@naver.com\', \'2580\', {lon}, {lat}, \'kakao\', \'abe3\')  ## 예시\n                cur.execute(sql)\n                sql = \'select * from client;\'\n                cur.execute(sql)\n                results = cur.fetchall()\n                for result in results:\n                    print(result)\n    print(\'\nfinish!\n\', \'-----\' * 20)\n    print(reg)\n    print(lat, lon)\n'

# %%
from geopy.geocoders import Nominatim

geo_local = Nominatim(user_agent = 'South Korea')
reg_beg = '용인시 처인구 역북동 명지로60번길 8-3'
reg_fin = '서울시 양천구 목동서로 155'
def geocoding(address):
    
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y
    
    except :
        return [0,0]
lon_beg = geocoding(reg_beg)[1]
lat_beg = geocoding(reg_beg)[0]
lon_fin = geocoding(reg_fin)[1]
lat_fin = geocoding(reg_fin)[0]
print(reg_beg)
print(lat_beg, lon_beg)
print(reg_fin)
print(lat_fin, lon_fin)
lon_beg = str(lon_beg)
lat_beg = str(lat_beg)
lon_fin = str(lon_fin)
lat_fin = str(lat_fin)
# Out:
# 용인시 처인구 역북동 명지로60번길 8-3
# 37.2311148 127.1871807
# 서울시 양천구 목동서로 155
# 37.5384905 126.8835659

# %%
from datetime import datetime
now = datetime.now()
print(now)
import urllib.request, json
def transit_route(origin_lat, origin_lon, destination_lat,destination_lon):
    #Google MapsDdirections API endpoint
    endpoint = "https://maps.googleapis.com/maps/api/directions/json?"
    api_key= "AIzaSyBRRvsR_jj8_NajJiFRcIBl3_Hc-3eicOA"
    nav_request = 'origin={},{}&destination={},{}&mode=transit&transit_routing_preference=fewer_transfers&key={}'.format(origin_lat, origin_lon, destination_lat ,destination_lon,api_key)
    request = endpoint + nav_request
    #Sends the request and reads the response.
    response = urllib.request.urlopen(request).read()
    #Loads response as JSON
    directions = json.loads(response)
    return directions
# Out:
# 2022-12-09 15:02:52.161831

# %%
transit_route(lat_beg, lon_beg, lat_fin, lon_fin)
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJcccfVctRezURL6s9HzI1IgI',
#    'types': ['cafe', 'establishment', 'food', 'point_of_interest']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJVbRro76efDURtO--tC2IKN0',
#    'types': ['establishment', 'point_of_interest']}],
#  'routes': [{'bounds': {'northeast': {'lat': 37.5391786, 'lng': 127.190686},
#     'southwest': {'lat': 37.2311148, 'lng': 126.882083}},
#    'copyrights': 'Map data ©2022 TMap Mobility',
#    'legs': [{'arrival_time': {'text': '5:15\u202fPM',
#       'time_zone': 'Asia/Seoul',
#       'value': 1670573753},
#      'departure_time': {'text': '3:21\u202fPM',
#       'time_zone': 'Asia/Seoul',
#       'value': 1670566888},
#      'distance': {'text': '58.4 km', 'value': 58397},
#      'duration': {'text': '1 hour 54 mins', 'value': 6865},
#      'end_address': '20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#      'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#      'start_address': '60번길 8-14 Myeongji-ro, Cheoin-gu, Yongin-si, Gyeonggi-do, South Korea',
#      'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#      'steps': [{'distance': {'text': '0.9 km', 'value': 868},
#        'duration': {'text': '15 mins', 'value': 872},
#        'end_location': {'lat': 37.238068, 'lng': 127.190282},
#        'html_instructions': 'Walk to Myongji Univ. Station',
#        'polyline': {'points': 'mufbF{fhgWoj@}T?pA'},
#        'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#        'steps': [{'distance': {'text': '0.8 km', 'value': 833},
#          'duration': {'text': '14 mins', 'value': 834},
#          'end_location': {'lat': 37.238069, 'lng': 127.190686},
#          'polyline': {'points': 'mufbF{fhgWoj@}T'},
#          'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '1 m', 'value': 0},
#          'duration': {'text': '1 min', 'value': 34},
#          'end_location': {'lat': 37.238069, 'lng': 127.190686},
#          'html_instructions': 'Take entrance <span class="location">2</span>',
#          'polyline': {'points': '}`hbFy|hgW'},
#          'start_location': {'lat': 37.238069, 'lng': 127.190686},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '1 m', 'value': 0},
#          'duration': {'text': '1 min', 'value': 0},
#          'end_location': {'lat': 37.238069, 'lng': 127.190686},
#          'polyline': {'points': '}`hbFy|hgW'},
#          'start_location': {'lat': 37.238069, 'lng': 127.190686},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '35 m', 'value': 35},
#          'duration': {'text': '1 min', 'value': 4},
#          'end_location': {'lat': 37.238068, 'lng': 127.190282},
#          'polyline': {'points': '}`hbFy|hgW?pA'},
#          'start_location': {'lat': 37.238069, 'lng': 127.190686},
#          'travel_mode': 'WALKING'}],
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '10.1 km', 'value': 10059},
#        'duration': {'text': '16 mins', 'value': 960},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'html_instructions': 'Subway towards 1701',
#        'polyline': {'points': '}`hbFgzhgWWp@k@zBO|@K|@Eh@GrDIjEItBMvBKrAW~B_@fCkAbJEfAE|@?p@?hADvARbEFnA@v@f@hNFjB@t@?n@El@El@UbAu@nCiCfIyBhHuAlE[t@Yj@sArB[f@Y\\uGzHkAfAk@l@mCdD_@d@QPSPWJWJa@L]Ha@?a@Ga@Oa@Qg@]kAmAmCsCyHiImAeAy@i@aA[]Io@KWE_@Ak@AaADoATo@T]Pg@Zy@n@qBvB}AzAaDvCkCpCgAz@_BdAaEtCkAbAw@`A}B`D_CfDqCtDiCxCe@h@A@]Z}E|D{FjFuCbDiCjCwBtAuIxEaCvAaC|AkCfBeD`CkClBiAbAmArAmAhAaAl@g@XsCpAgBl@}@b@s@b@{@r@i@h@g@v@[r@i@vAUz@Kj@Kx@Gr@Cr@?r@@jADv@H|@Nx@Pt@x@jC?BRv@`AxDnDlNRv@\\dAl@rAx@lAb@b@r@h@fA`@xCn@dCh@`@L^TZ^xAbCzAbDl@lAj@xAd@xAb@zAX|AVdBLlADbAFtA?pA@rAIvAKtAWzA]pBu@dCw@tB_@p@k@~@u@pAsA`C_@t@?@W\\eApAeBpBmBlB_A|@_A`Ay@fA[`@{EdHeE`GQZ[v@Mt@O~AOvBOxCGhACfB@j@e@zC'},
#        'start_location': {'lat': 37.238068, 'lng': 127.190282},
#        'transit_details': {'arrival_stop': {'location': {'lat': 37.275664,
#           'lng': 127.115956},
#          'name': 'Giheung'},
#         'arrival_time': {'text': '3:52\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670568720},
#         'departure_stop': {'location': {'lat': 37.238068, 'lng': 127.190282},
#          'name': 'Myongji Univ. Station'},
#         'departure_time': {'text': '3:36\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670567760},
#         'headsign': '1701',
#         'line': {'agencies': [{'name': '용인경량전철주신회사',
#            'url': 'http://www.ever-line.co.kr/everline/index.php'}],
#          'color': '#5eae53',
#          'name': '수도권전철',
#          'short_name': '용인 경전철',
#          'text_color': '#ffffff',
#          'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#           'name': 'Subway',
#           'type': 'SUBWAY'}},
#         'num_stops': 8},
#        'travel_mode': 'TRANSIT'},
#       {'distance': {'text': '0.1 km', 'value': 106},
#        'duration': {'text': '2 mins', 'value': 107},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'html_instructions': 'Walk to Giheung',
#        'polyline': {'points': '{kobFwizfWrAy@sAx@'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'steps': [{'distance': {'text': '1 m', 'value': 0},
#          'duration': {'text': '1 min', 'value': 0},
#          'end_location': {'lat': 37.275664, 'lng': 127.115956},
#          'polyline': {'points': '{kobFwizfW'},
#          'start_location': {'lat': 37.275664, 'lng': 127.115956},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '1 m', 'value': 0},
#          'duration': {'text': '1 min', 'value': 0},
#          'end_location': {'lat': 37.275664, 'lng': 127.115956},
#          'polyline': {'points': '{kobFwizfW'},
#          'start_location': {'lat': 37.275664, 'lng': 127.115956},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '1 m', 'value': 0},
#          'duration': {'text': '1 min', 'value': 0},
#          'end_location': {'lat': 37.275664, 'lng': 127.115956},
#          'polyline': {'points': '{kobFwizfW'},
#          'start_location': {'lat': 37.275664, 'lng': 127.115956},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '1 m', 'value': 0},
#          'duration': {'text': '1 min', 'value': 0},
#          'end_location': {'lat': 37.275664, 'lng': 127.115956},
#          'polyline': {'points': '{kobFwizfW'},
#          'start_location': {'lat': 37.275664, 'lng': 127.115956},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '53 m', 'value': 53},
#          'duration': {'text': '1 min', 'value': 54},
#          'end_location': {'lat': 37.27524, 'lng': 127.116251},
#          'html_instructions': 'Take exit <span class="location">3</span>',
#          'polyline': {'points': '{kobFwizfWrAy@'},
#          'start_location': {'lat': 37.275664, 'lng': 127.115956},
#          'travel_mode': 'WALKING'},
#         {'distance': {'text': '53 m', 'value': 53},
#          'duration': {'text': '1 min', 'value': 53},
#          'end_location': {'lat': 37.275664, 'lng': 127.115956},
#          'polyline': {'points': 'giobFqkzfWsAx@'},
#          'start_location': {'lat': 37.27524, 'lng': 127.116251},
#          'travel_mode': 'WALKING'}],
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '13.6 km', 'value': 13565},
#        'duration': {'text': '21 mins', 'value': 1260},
#        'end_location': {'lat': 37.266251, 'lng': 127.000034},
#        'html_instructions': 'Subway towards 11109',
#        'polyline': {'points': '{kobFwizfW?@B?vCAxGAvTEbOAxHInA?fBHrCl@z@X|@b@|@z@x@dBl@rAv@~Bv@|C`@zCZxDDtAF`K?@DvDXdEh@jPHpBV~Fl@|Nn@hQJrJKxJS|Gy@|KwDv\\O|AAfBH|AP|AZnBf@pBj@xAn@rAjDxDtDlD?@nDdDdk@ji@@@rBfB`JdIrMxLbAdAb@z@r@pBZdBL|AJnGHjHArJS`HDvFLvFn@hXEjBM|AK|@e@tBcAxBo_@bo@a@p@a@b@}@t@cCbBgIzEmA~@o@r@e@t@c@p@}@pBwBfDmBbB}@`@mAXyJnAs@Xw@`@u@n@k@f@s@dAs@zA_@nAuCjP_G~]cHde@{@~HwA|Jc@bDe@jDS~BWlBy@|Ei@lBkAbDcCnFuAdD_@|Aa@dCOrCAlBD|BTtB\\~AdHhWlApEQJ'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'transit_details': {'arrival_stop': {'location': {'lat': 37.266251,
#           'lng': 127.000034},
#          'name': 'Suwon Station'},
#         'arrival_time': {'text': '4:18\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670570280},
#         'departure_stop': {'location': {'lat': 37.275664, 'lng': 127.115956},
#          'name': 'Giheung'},
#         'departure_time': {'text': '3:57\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670569020},
#         'headsign': '11109',
#         'line': {'agencies': [{'name': '코레일', 'url': 'http://www.odsay.com/'}],
#          'color': '#f2c305',
#          'name': '수도권 전철 수인·분당선',
#          'short_name': '수인.분당선',
#          'text_color': '#000000',
#          'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#           'name': 'Subway',
#           'type': 'SUBWAY'}},
#         'num_stops': 8},
#        'travel_mode': 'TRANSIT'},
#       {'distance': {'text': '28.9 km', 'value': 28900},
#        'duration': {'text': '23 mins', 'value': 1380},
#        'end_location': {'lat': 37.5154133, 'lng': 126.9071288},
#        'html_instructions': 'Train towards To Yongsan',
#        'polyline': {'points': 'opmbF{scfWyto@hbQ'},
#        'start_location': {'lat': 37.2661617, 'lng': 126.9998207},
#        'transit_details': {'arrival_stop': {'location': {'lat': 37.5154133,
#           'lng': 126.9071288},
#          'name': 'Yeongdeungpo'},
#         'arrival_time': {'text': '4:46\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670571960},
#         'departure_stop': {'location': {'lat': 37.2661617, 'lng': 126.9998207},
#          'name': 'Suwon Station'},
#         'departure_time': {'text': '4:23\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670570580},
#         'headsign': 'To Yongsan',
#         'line': {'agencies': [{'name': 'korail',
#            'url': 'https://ga-g.onntapi.com/#1&en'}],
#          'name': 'Honam',
#          'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/rail2.png',
#           'name': 'Train',
#           'type': 'HEAVY_RAIL'}},
#         'num_stops': 1,
#         'trip_short_name': 'Mugunghwa No.1406'},
#        'travel_mode': 'TRANSIT'},
#       {'distance': {'text': '0.2 km', 'value': 244},
#        'duration': {'text': '4 mins', 'value': 244},
#        'end_location': {'lat': 37.517505, 'lng': 126.906263},
#        'html_instructions': 'Walk to Kyungbang Time Square, Shinsegae Department Store',
#        'polyline': {'points': 'if~cFqpqeWaLlD'},
#        'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#        'steps': [{'distance': {'text': '0.2 km', 'value': 244},
#          'duration': {'text': '4 mins', 'value': 244},
#          'end_location': {'lat': 37.517505, 'lng': 126.906263},
#          'polyline': {'points': 'if~cFqpqeWaLlD'},
#          'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#          'travel_mode': 'WALKING'}],
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '4.3 km', 'value': 4332},
#        'duration': {'text': '12 mins', 'value': 715},
#        'end_location': {'lat': 37.538003, 'lng': 126.882083},
#        'html_instructions': 'Bus towards Mokdong',
#        'polyline': {'points': 'ks~cFckqeWACgLvEk@v@c@p@g@xAKpAWzCGl@?BqDhc@?@_@hEORSBgG}@A?qMqBwCe@A?mG_Ae@Aa@Fc@TKXeAzBELKViG`Pg@jCgEl[}DxZMByC[A?oFk@iBPeBl@iD|AiAj@cAAgAwECKy@aDW_@UKc@?WPs@\\i@Nw@Ia@S[EYRrAvFvBjI'},
#        'start_location': {'lat': 37.517505, 'lng': 126.906263},
#        'transit_details': {'arrival_stop': {'location': {'lat': 37.538003,
#           'lng': 126.882083},
#          'name': '월촌중학교.목동1단지'},
#         'arrival_time': {'text': '5:10\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670573429},
#         'departure_stop': {'location': {'lat': 37.517505, 'lng': 126.906263},
#          'name': 'Kyungbang Time Square, Shinsegae Department Store'},
#         'departure_time': {'text': '4:58\u202fPM',
#          'time_zone': 'Asia/Seoul',
#          'value': 1670572714},
#         'headsign': 'Mokdong',
#         'headway': 480,
#         'line': {'agencies': [{'name': '서울특별시버스운송사업조합',
#            'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}],
#          'color': '#0abb0c',
#          'name': '서울 지선버스',
#          'short_name': '6637',
#          'text_color': '#ffffff',
#          'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#           'name': 'Bus',
#           'type': 'BUS'}},
#         'num_stops': 8},
#        'travel_mode': 'TRANSIT'},
#       {'distance': {'text': '0.3 km', 'value': 323},
#        'duration': {'text': '5 mins', 'value': 324},
#        'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#        'html_instructions': 'Walk to 20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#        'polyline': {'points': 'osbdF_tleWkF_T'},
#        'start_location': {'lat': 37.538003, 'lng': 126.882083},
#        'steps': [{'distance': {'text': '0.3 km', 'value': 323},
#          'duration': {'text': '5 mins', 'value': 324},
#          'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#          'polyline': {'points': 'osbdF_tleWkF_T'},
#          'start_location': {'lat': 37.538003, 'lng': 126.882083},
#          'travel_mode': 'WALKING'}],
#        'travel_mode': 'WALKING'}],
#      'traffic_speed_entry': [],
#      'via_waypoint': []}],
#    'overview_polyline': {'points': 'mufbF{fhgWoj@}T?pAWp@k@zBO|@QfBQ~JWlFc@rEkBjNKdC?zB`@jJh@`PH`DE|AEl@UbAu@nCiCfIoEvNu@`BoBzCY\\uGzHkAfAyDrEq@v@k@\\y@X]Ha@?a@Ga@Oa@Qg@]yEaFyHiImAeAy@i@aA[mAUw@Gk@AaADoATo@TeAl@y@n@qBvB_GrFkCpCgAz@aHzEkAbAw@`A}FhIqCtDiCxCg@j@{FxE{FjFuCbDiCjCwBtAwMpHmGdEeD`CkClBiAbA{C|CiBfAsCpAgBl@}@b@s@b@eB|Ag@v@[r@_ArCWdBKfB@~BNtB`@nBx@nCtApFbEdP\\dAl@rAx@lAb@b@r@h@fA`@~GxA`@L^TZ^xAbChCpFpArDb@zAX|Ad@rDLxC@dDUlDu@lEu@dCw@tBkApBiCrE_@v@}AnBeBpBmBlB_C~BuAhBaLfPm@rAMt@O~A_@pGKpD@j@e@zCrAy@sAx@B@pLCzd@GhKIfBHrCl@z@X|@b@|@z@x@dBl@rAv@~Bv@|C`@zCZxDDtAFbKDvDXdEr@|SdA|Vn@hQJrJKxJS|Gy@|KwDv\\O|AAfBH|AP|AZnBf@pBj@xAn@rAjDxDtDlDnDfDfk@li@tMlLrMxLbAdAb@z@r@pBZdBL|ATzPArJS`HDvF|@``@EjBM|AK|@e@tBcAxBo_@bo@a@p@a@b@}@t@cCbBgIzEmA~@o@r@iAfB}@pBwBfDmBbB}@`@mAXyJnAs@Xw@`@aBvAs@dAs@zA_@nAuCjP_G~]cHde@{@~H{B`Pe@jDS~BWlBy@|Ei@lBkAbDcCnFuAdD_@|Aa@dCOrCAlBD|BTtB\\~AdHhWlApEQJPh@yto@hbQaLlDACgLvEk@v@c@p@g@xAc@lFGp@qDjc@_@hEORSBgG}@sMqByCe@mG_Ae@Aa@Fc@TqAtCQd@iG`Pg@jCeKfw@MByC[qFk@iBPeBl@iD|AiAj@cAAkAcFy@aDW_@UKc@?kAn@i@Nw@Ia@S[EYRrAvFvBjIkF_T'},
#    'summary': '',
#    'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#    'waypoint_order': []}],
#  'status': 'OK'}

# %%
transit_route(lat_beg, lon_beg, lat_fin, lon_fin)['geocoded_waypoints']
# Out:
# [{'geocoder_status': 'OK',
#   'place_id': 'ChIJcccfVctRezURL6s9HzI1IgI',
#   'types': ['cafe', 'establishment', 'food', 'point_of_interest']},
#  {'geocoder_status': 'OK',
#   'place_id': 'ChIJVbRro76efDURtO--tC2IKN0',
#   'types': ['establishment', 'point_of_interest']}]

# %%
route = transit_route(lat_beg, lon_beg, lat_fin, lon_fin)['routes'][0]
route
# Out:
# {'bounds': {'northeast': {'lat': 37.5391786, 'lng': 127.190686},
#   'southwest': {'lat': 37.2311148, 'lng': 126.882083}},
#  'copyrights': 'Map data ©2022 TMap Mobility',
#  'legs': [{'arrival_time': {'text': '5:15\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670573753},
#    'departure_time': {'text': '3:21\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670566888},
#    'distance': {'text': '58.4 km', 'value': 58397},
#    'duration': {'text': '1 hour 54 mins', 'value': 6865},
#    'end_address': '20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#    'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#    'start_address': '60번길 8-14 Myeongji-ro, Cheoin-gu, Yongin-si, Gyeonggi-do, South Korea',
#    'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#    'steps': [{'distance': {'text': '0.9 km', 'value': 868},
#      'duration': {'text': '15 mins', 'value': 872},
#      'end_location': {'lat': 37.238068, 'lng': 127.190282},
#      'html_instructions': 'Walk to Myongji Univ. Station',
#      'polyline': {'points': 'mufbF{fhgWoj@}T?pA'},
#      'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#      'steps': [{'distance': {'text': '0.8 km', 'value': 833},
#        'duration': {'text': '14 mins', 'value': 834},
#        'end_location': {'lat': 37.238069, 'lng': 127.190686},
#        'polyline': {'points': 'mufbF{fhgWoj@}T'},
#        'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '1 m', 'value': 0},
#        'duration': {'text': '1 min', 'value': 34},
#        'end_location': {'lat': 37.238069, 'lng': 127.190686},
#        'html_instructions': 'Take entrance <span class="location">2</span>',
#        'polyline': {'points': '}`hbFy|hgW'},
#        'start_location': {'lat': 37.238069, 'lng': 127.190686},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '1 m', 'value': 0},
#        'duration': {'text': '1 min', 'value': 0},
#        'end_location': {'lat': 37.238069, 'lng': 127.190686},
#        'polyline': {'points': '}`hbFy|hgW'},
#        'start_location': {'lat': 37.238069, 'lng': 127.190686},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '35 m', 'value': 35},
#        'duration': {'text': '1 min', 'value': 4},
#        'end_location': {'lat': 37.238068, 'lng': 127.190282},
#        'polyline': {'points': '}`hbFy|hgW?pA'},
#        'start_location': {'lat': 37.238069, 'lng': 127.190686},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '10.1 km', 'value': 10059},
#      'duration': {'text': '16 mins', 'value': 960},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'html_instructions': 'Subway towards 1701',
#      'polyline': {'points': '}`hbFgzhgWWp@k@zBO|@K|@Eh@GrDIjEItBMvBKrAW~B_@fCkAbJEfAE|@?p@?hADvARbEFnA@v@f@hNFjB@t@?n@El@El@UbAu@nCiCfIyBhHuAlE[t@Yj@sArB[f@Y\\uGzHkAfAk@l@mCdD_@d@QPSPWJWJa@L]Ha@?a@Ga@Oa@Qg@]kAmAmCsCyHiImAeAy@i@aA[]Io@KWE_@Ak@AaADoATo@T]Pg@Zy@n@qBvB}AzAaDvCkCpCgAz@_BdAaEtCkAbAw@`A}B`D_CfDqCtDiCxCe@h@A@]Z}E|D{FjFuCbDiCjCwBtAuIxEaCvAaC|AkCfBeD`CkClBiAbAmArAmAhAaAl@g@XsCpAgBl@}@b@s@b@{@r@i@h@g@v@[r@i@vAUz@Kj@Kx@Gr@Cr@?r@@jADv@H|@Nx@Pt@x@jC?BRv@`AxDnDlNRv@\\dAl@rAx@lAb@b@r@h@fA`@xCn@dCh@`@L^TZ^xAbCzAbDl@lAj@xAd@xAb@zAX|AVdBLlADbAFtA?pA@rAIvAKtAWzA]pBu@dCw@tB_@p@k@~@u@pAsA`C_@t@?@W\\eApAeBpBmBlB_A|@_A`Ay@fA[`@{EdHeE`GQZ[v@Mt@O~AOvBOxCGhACfB@j@e@zC'},
#      'start_location': {'lat': 37.238068, 'lng': 127.190282},
#      'transit_details': {'arrival_stop': {'location': {'lat': 37.275664,
#         'lng': 127.115956},
#        'name': 'Giheung'},
#       'arrival_time': {'text': '3:52\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670568720},
#       'departure_stop': {'location': {'lat': 37.238068, 'lng': 127.190282},
#        'name': 'Myongji Univ. Station'},
#       'departure_time': {'text': '3:36\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670567760},
#       'headsign': '1701',
#       'line': {'agencies': [{'name': '용인경량전철주신회사',
#          'url': 'http://www.ever-line.co.kr/everline/index.php'}],
#        'color': '#5eae53',
#        'name': '수도권전철',
#        'short_name': '용인 경전철',
#        'text_color': '#ffffff',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#         'name': 'Subway',
#         'type': 'SUBWAY'}},
#       'num_stops': 8},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '0.1 km', 'value': 106},
#      'duration': {'text': '2 mins', 'value': 107},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'html_instructions': 'Walk to Giheung',
#      'polyline': {'points': '{kobFwizfWrAy@sAx@'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'steps': [{'distance': {'text': '1 m', 'value': 0},
#        'duration': {'text': '1 min', 'value': 0},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'polyline': {'points': '{kobFwizfW'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '1 m', 'value': 0},
#        'duration': {'text': '1 min', 'value': 0},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'polyline': {'points': '{kobFwizfW'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '1 m', 'value': 0},
#        'duration': {'text': '1 min', 'value': 0},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'polyline': {'points': '{kobFwizfW'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '1 m', 'value': 0},
#        'duration': {'text': '1 min', 'value': 0},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'polyline': {'points': '{kobFwizfW'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '53 m', 'value': 53},
#        'duration': {'text': '1 min', 'value': 54},
#        'end_location': {'lat': 37.27524, 'lng': 127.116251},
#        'html_instructions': 'Take exit <span class="location">3</span>',
#        'polyline': {'points': '{kobFwizfWrAy@'},
#        'start_location': {'lat': 37.275664, 'lng': 127.115956},
#        'travel_mode': 'WALKING'},
#       {'distance': {'text': '53 m', 'value': 53},
#        'duration': {'text': '1 min', 'value': 53},
#        'end_location': {'lat': 37.275664, 'lng': 127.115956},
#        'polyline': {'points': 'giobFqkzfWsAx@'},
#        'start_location': {'lat': 37.27524, 'lng': 127.116251},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '13.6 km', 'value': 13565},
#      'duration': {'text': '21 mins', 'value': 1260},
#      'end_location': {'lat': 37.266251, 'lng': 127.000034},
#      'html_instructions': 'Subway towards 11109',
#      'polyline': {'points': '{kobFwizfW?@B?vCAxGAvTEbOAxHInA?fBHrCl@z@X|@b@|@z@x@dBl@rAv@~Bv@|C`@zCZxDDtAF`K?@DvDXdEh@jPHpBV~Fl@|Nn@hQJrJKxJS|Gy@|KwDv\\O|AAfBH|AP|AZnBf@pBj@xAn@rAjDxDtDlD?@nDdDdk@ji@@@rBfB`JdIrMxLbAdAb@z@r@pBZdBL|AJnGHjHArJS`HDvFLvFn@hXEjBM|AK|@e@tBcAxBo_@bo@a@p@a@b@}@t@cCbBgIzEmA~@o@r@e@t@c@p@}@pBwBfDmBbB}@`@mAXyJnAs@Xw@`@u@n@k@f@s@dAs@zA_@nAuCjP_G~]cHde@{@~HwA|Jc@bDe@jDS~BWlBy@|Ei@lBkAbDcCnFuAdD_@|Aa@dCOrCAlBD|BTtB\\~AdHhWlApEQJ'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'transit_details': {'arrival_stop': {'location': {'lat': 37.266251,
#         'lng': 127.000034},
#        'name': 'Suwon Station'},
#       'arrival_time': {'text': '4:18\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670570280},
#       'departure_stop': {'location': {'lat': 37.275664, 'lng': 127.115956},
#        'name': 'Giheung'},
#       'departure_time': {'text': '3:57\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670569020},
#       'headsign': '11109',
#       'line': {'agencies': [{'name': '코레일', 'url': 'http://www.odsay.com/'}],
#        'color': '#f2c305',
#        'name': '수도권 전철 수인·분당선',
#        'short_name': '수인.분당선',
#        'text_color': '#000000',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#         'name': 'Subway',
#         'type': 'SUBWAY'}},
#       'num_stops': 8},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '28.9 km', 'value': 28900},
#      'duration': {'text': '23 mins', 'value': 1380},
#      'end_location': {'lat': 37.5154133, 'lng': 126.9071288},
#      'html_instructions': 'Train towards To Yongsan',
#      'polyline': {'points': 'opmbF{scfWyto@hbQ'},
#      'start_location': {'lat': 37.2661617, 'lng': 126.9998207},
#      'transit_details': {'arrival_stop': {'location': {'lat': 37.5154133,
#         'lng': 126.9071288},
#        'name': 'Yeongdeungpo'},
#       'arrival_time': {'text': '4:46\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670571960},
#       'departure_stop': {'location': {'lat': 37.2661617, 'lng': 126.9998207},
#        'name': 'Suwon Station'},
#       'departure_time': {'text': '4:23\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670570580},
#       'headsign': 'To Yongsan',
#       'line': {'agencies': [{'name': 'korail',
#          'url': 'https://ga-g.onntapi.com/#1&en'}],
#        'name': 'Honam',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/rail2.png',
#         'name': 'Train',
#         'type': 'HEAVY_RAIL'}},
#       'num_stops': 1,
#       'trip_short_name': 'Mugunghwa No.1406'},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '0.2 km', 'value': 244},
#      'duration': {'text': '4 mins', 'value': 244},
#      'end_location': {'lat': 37.517505, 'lng': 126.906263},
#      'html_instructions': 'Walk to Kyungbang Time Square, Shinsegae Department Store',
#      'polyline': {'points': 'if~cFqpqeWaLlD'},
#      'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#      'steps': [{'distance': {'text': '0.2 km', 'value': 244},
#        'duration': {'text': '4 mins', 'value': 244},
#        'end_location': {'lat': 37.517505, 'lng': 126.906263},
#        'polyline': {'points': 'if~cFqpqeWaLlD'},
#        'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '4.3 km', 'value': 4332},
#      'duration': {'text': '12 mins', 'value': 715},
#      'end_location': {'lat': 37.538003, 'lng': 126.882083},
#      'html_instructions': 'Bus towards Mokdong',
#      'polyline': {'points': 'ks~cFckqeWACgLvEk@v@c@p@g@xAKpAWzCGl@?BqDhc@?@_@hEORSBgG}@A?qMqBwCe@A?mG_Ae@Aa@Fc@TKXeAzBELKViG`Pg@jCgEl[}DxZMByC[A?oFk@iBPeBl@iD|AiAj@cAAgAwECKy@aDW_@UKc@?WPs@\\i@Nw@Ia@S[EYRrAvFvBjI'},
#      'start_location': {'lat': 37.517505, 'lng': 126.906263},
#      'transit_details': {'arrival_stop': {'location': {'lat': 37.538003,
#         'lng': 126.882083},
#        'name': '월촌중학교.목동1단지'},
#       'arrival_time': {'text': '5:10\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670573429},
#       'departure_stop': {'location': {'lat': 37.517505, 'lng': 126.906263},
#        'name': 'Kyungbang Time Square, Shinsegae Department Store'},
#       'departure_time': {'text': '4:58\u202fPM',
#        'time_zone': 'Asia/Seoul',
#        'value': 1670572714},
#       'headsign': 'Mokdong',
#       'headway': 480,
#       'line': {'agencies': [{'name': '서울특별시버스운송사업조합',
#          'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}],
#        'color': '#0abb0c',
#        'name': '서울 지선버스',
#        'short_name': '6637',
#        'text_color': '#ffffff',
#        'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#         'name': 'Bus',
#         'type': 'BUS'}},
#       'num_stops': 8},
#      'travel_mode': 'TRANSIT'},
#     {'distance': {'text': '0.3 km', 'value': 323},
#      'duration': {'text': '5 mins', 'value': 324},
#      'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#      'html_instructions': 'Walk to 20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#      'polyline': {'points': 'osbdF_tleWkF_T'},
#      'start_location': {'lat': 37.538003, 'lng': 126.882083},
#      'steps': [{'distance': {'text': '0.3 km', 'value': 323},
#        'duration': {'text': '5 mins', 'value': 324},
#        'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#        'polyline': {'points': 'osbdF_tleWkF_T'},
#        'start_location': {'lat': 37.538003, 'lng': 126.882083},
#        'travel_mode': 'WALKING'}],
#      'travel_mode': 'WALKING'}],
#    'traffic_speed_entry': [],
#    'via_waypoint': []}],
#  'overview_polyline': {'points': 'mufbF{fhgWoj@}T?pAWp@k@zBO|@QfBQ~JWlFc@rEkBjNKdC?zB`@jJh@`PH`DE|AEl@UbAu@nCiCfIoEvNu@`BoBzCY\\uGzHkAfAyDrEq@v@k@\\y@X]Ha@?a@Ga@Oa@Qg@]yEaFyHiImAeAy@i@aA[mAUw@Gk@AaADoATo@TeAl@y@n@qBvB_GrFkCpCgAz@aHzEkAbAw@`A}FhIqCtDiCxCg@j@{FxE{FjFuCbDiCjCwBtAwMpHmGdEeD`CkClBiAbA{C|CiBfAsCpAgBl@}@b@s@b@eB|Ag@v@[r@_ArCWdBKfB@~BNtB`@nBx@nCtApFbEdP\\dAl@rAx@lAb@b@r@h@fA`@~GxA`@L^TZ^xAbChCpFpArDb@zAX|Ad@rDLxC@dDUlDu@lEu@dCw@tBkApBiCrE_@v@}AnBeBpBmBlB_C~BuAhBaLfPm@rAMt@O~A_@pGKpD@j@e@zCrAy@sAx@B@pLCzd@GhKIfBHrCl@z@X|@b@|@z@x@dBl@rAv@~Bv@|C`@zCZxDDtAFbKDvDXdEr@|SdA|Vn@hQJrJKxJS|Gy@|KwDv\\O|AAfBH|AP|AZnBf@pBj@xAn@rAjDxDtDlDnDfDfk@li@tMlLrMxLbAdAb@z@r@pBZdBL|ATzPArJS`HDvF|@``@EjBM|AK|@e@tBcAxBo_@bo@a@p@a@b@}@t@cCbBgIzEmA~@o@r@iAfB}@pBwBfDmBbB}@`@mAXyJnAs@Xw@`@aBvAs@dAs@zA_@nAuCjP_G~]cHde@{@~H{B`Pe@jDS~BWlBy@|Ei@lBkAbDcCnFuAdD_@|Aa@dCOrCAlBD|BTtB\\~AdHhWlApEQJPh@yto@hbQaLlDACgLvEk@v@c@p@g@xAc@lFGp@qDjc@_@hEORSBgG}@sMqByCe@mG_Ae@Aa@Fc@TqAtCQd@iG`Pg@jCeKfw@MByC[qFk@iBPeBl@iD|AiAj@cAAkAcFy@aDW_@UKc@?kAn@i@Nw@Ia@S[EYRrAvFvBjIkF_T'},
#  'summary': '',
#  'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#  'waypoint_order': []}

# %%
route = route['legs'][0]
route
# Out:
# {'arrival_time': {'text': '5:15\u202fPM',
#   'time_zone': 'Asia/Seoul',
#   'value': 1670573753},
#  'departure_time': {'text': '3:21\u202fPM',
#   'time_zone': 'Asia/Seoul',
#   'value': 1670566888},
#  'distance': {'text': '58.4 km', 'value': 58397},
#  'duration': {'text': '1 hour 54 mins', 'value': 6865},
#  'end_address': '20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#  'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#  'start_address': '60번길 8-14 Myeongji-ro, Cheoin-gu, Yongin-si, Gyeonggi-do, South Korea',
#  'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#  'steps': [{'distance': {'text': '0.9 km', 'value': 868},
#    'duration': {'text': '15 mins', 'value': 872},
#    'end_location': {'lat': 37.238068, 'lng': 127.190282},
#    'html_instructions': 'Walk to Myongji Univ. Station',
#    'polyline': {'points': 'mufbF{fhgWoj@}T?pA'},
#    'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#    'steps': [{'distance': {'text': '0.8 km', 'value': 833},
#      'duration': {'text': '14 mins', 'value': 834},
#      'end_location': {'lat': 37.238069, 'lng': 127.190686},
#      'polyline': {'points': 'mufbF{fhgWoj@}T'},
#      'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 34},
#      'end_location': {'lat': 37.238069, 'lng': 127.190686},
#      'html_instructions': 'Take entrance <span class="location">2</span>',
#      'polyline': {'points': '}`hbFy|hgW'},
#      'start_location': {'lat': 37.238069, 'lng': 127.190686},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'end_location': {'lat': 37.238069, 'lng': 127.190686},
#      'polyline': {'points': '}`hbFy|hgW'},
#      'start_location': {'lat': 37.238069, 'lng': 127.190686},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '35 m', 'value': 35},
#      'duration': {'text': '1 min', 'value': 4},
#      'end_location': {'lat': 37.238068, 'lng': 127.190282},
#      'polyline': {'points': '}`hbFy|hgW?pA'},
#      'start_location': {'lat': 37.238069, 'lng': 127.190686},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '10.1 km', 'value': 10059},
#    'duration': {'text': '16 mins', 'value': 960},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'html_instructions': 'Subway towards 1701',
#    'polyline': {'points': '}`hbFgzhgWWp@k@zBO|@K|@Eh@GrDIjEItBMvBKrAW~B_@fCkAbJEfAE|@?p@?hADvARbEFnA@v@f@hNFjB@t@?n@El@El@UbAu@nCiCfIyBhHuAlE[t@Yj@sArB[f@Y\\uGzHkAfAk@l@mCdD_@d@QPSPWJWJa@L]Ha@?a@Ga@Oa@Qg@]kAmAmCsCyHiImAeAy@i@aA[]Io@KWE_@Ak@AaADoATo@T]Pg@Zy@n@qBvB}AzAaDvCkCpCgAz@_BdAaEtCkAbAw@`A}B`D_CfDqCtDiCxCe@h@A@]Z}E|D{FjFuCbDiCjCwBtAuIxEaCvAaC|AkCfBeD`CkClBiAbAmArAmAhAaAl@g@XsCpAgBl@}@b@s@b@{@r@i@h@g@v@[r@i@vAUz@Kj@Kx@Gr@Cr@?r@@jADv@H|@Nx@Pt@x@jC?BRv@`AxDnDlNRv@\\dAl@rAx@lAb@b@r@h@fA`@xCn@dCh@`@L^TZ^xAbCzAbDl@lAj@xAd@xAb@zAX|AVdBLlADbAFtA?pA@rAIvAKtAWzA]pBu@dCw@tB_@p@k@~@u@pAsA`C_@t@?@W\\eApAeBpBmBlB_A|@_A`Ay@fA[`@{EdHeE`GQZ[v@Mt@O~AOvBOxCGhACfB@j@e@zC'},
#    'start_location': {'lat': 37.238068, 'lng': 127.190282},
#    'transit_details': {'arrival_stop': {'location': {'lat': 37.275664,
#       'lng': 127.115956},
#      'name': 'Giheung'},
#     'arrival_time': {'text': '3:52\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670568720},
#     'departure_stop': {'location': {'lat': 37.238068, 'lng': 127.190282},
#      'name': 'Myongji Univ. Station'},
#     'departure_time': {'text': '3:36\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670567760},
#     'headsign': '1701',
#     'line': {'agencies': [{'name': '용인경량전철주신회사',
#        'url': 'http://www.ever-line.co.kr/everline/index.php'}],
#      'color': '#5eae53',
#      'name': '수도권전철',
#      'short_name': '용인 경전철',
#      'text_color': '#ffffff',
#      'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#       'name': 'Subway',
#       'type': 'SUBWAY'}},
#     'num_stops': 8},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '0.1 km', 'value': 106},
#    'duration': {'text': '2 mins', 'value': 107},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'html_instructions': 'Walk to Giheung',
#    'polyline': {'points': '{kobFwizfWrAy@sAx@'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'steps': [{'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'polyline': {'points': '{kobFwizfW'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'polyline': {'points': '{kobFwizfW'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'polyline': {'points': '{kobFwizfW'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'polyline': {'points': '{kobFwizfW'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '53 m', 'value': 53},
#      'duration': {'text': '1 min', 'value': 54},
#      'end_location': {'lat': 37.27524, 'lng': 127.116251},
#      'html_instructions': 'Take exit <span class="location">3</span>',
#      'polyline': {'points': '{kobFwizfWrAy@'},
#      'start_location': {'lat': 37.275664, 'lng': 127.115956},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '53 m', 'value': 53},
#      'duration': {'text': '1 min', 'value': 53},
#      'end_location': {'lat': 37.275664, 'lng': 127.115956},
#      'polyline': {'points': 'giobFqkzfWsAx@'},
#      'start_location': {'lat': 37.27524, 'lng': 127.116251},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '13.6 km', 'value': 13565},
#    'duration': {'text': '21 mins', 'value': 1260},
#    'end_location': {'lat': 37.266251, 'lng': 127.000034},
#    'html_instructions': 'Subway towards 11109',
#    'polyline': {'points': '{kobFwizfW?@B?vCAxGAvTEbOAxHInA?fBHrCl@z@X|@b@|@z@x@dBl@rAv@~Bv@|C`@zCZxDDtAF`K?@DvDXdEh@jPHpBV~Fl@|Nn@hQJrJKxJS|Gy@|KwDv\\O|AAfBH|AP|AZnBf@pBj@xAn@rAjDxDtDlD?@nDdDdk@ji@@@rBfB`JdIrMxLbAdAb@z@r@pBZdBL|AJnGHjHArJS`HDvFLvFn@hXEjBM|AK|@e@tBcAxBo_@bo@a@p@a@b@}@t@cCbBgIzEmA~@o@r@e@t@c@p@}@pBwBfDmBbB}@`@mAXyJnAs@Xw@`@u@n@k@f@s@dAs@zA_@nAuCjP_G~]cHde@{@~HwA|Jc@bDe@jDS~BWlBy@|Ei@lBkAbDcCnFuAdD_@|Aa@dCOrCAlBD|BTtB\\~AdHhWlApEQJ'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'transit_details': {'arrival_stop': {'location': {'lat': 37.266251,
#       'lng': 127.000034},
#      'name': 'Suwon Station'},
#     'arrival_time': {'text': '4:18\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670570280},
#     'departure_stop': {'location': {'lat': 37.275664, 'lng': 127.115956},
#      'name': 'Giheung'},
#     'departure_time': {'text': '3:57\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670569020},
#     'headsign': '11109',
#     'line': {'agencies': [{'name': '코레일', 'url': 'http://www.odsay.com/'}],
#      'color': '#f2c305',
#      'name': '수도권 전철 수인·분당선',
#      'short_name': '수인.분당선',
#      'text_color': '#000000',
#      'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#       'name': 'Subway',
#       'type': 'SUBWAY'}},
#     'num_stops': 8},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '28.9 km', 'value': 28900},
#    'duration': {'text': '23 mins', 'value': 1380},
#    'end_location': {'lat': 37.5154133, 'lng': 126.9071288},
#    'html_instructions': 'Train towards To Yongsan',
#    'polyline': {'points': 'opmbF{scfWyto@hbQ'},
#    'start_location': {'lat': 37.2661617, 'lng': 126.9998207},
#    'transit_details': {'arrival_stop': {'location': {'lat': 37.5154133,
#       'lng': 126.9071288},
#      'name': 'Yeongdeungpo'},
#     'arrival_time': {'text': '4:46\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670571960},
#     'departure_stop': {'location': {'lat': 37.2661617, 'lng': 126.9998207},
#      'name': 'Suwon Station'},
#     'departure_time': {'text': '4:23\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670570580},
#     'headsign': 'To Yongsan',
#     'line': {'agencies': [{'name': 'korail',
#        'url': 'https://ga-g.onntapi.com/#1&en'}],
#      'name': 'Honam',
#      'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/rail2.png',
#       'name': 'Train',
#       'type': 'HEAVY_RAIL'}},
#     'num_stops': 1,
#     'trip_short_name': 'Mugunghwa No.1406'},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '0.2 km', 'value': 244},
#    'duration': {'text': '4 mins', 'value': 244},
#    'end_location': {'lat': 37.517505, 'lng': 126.906263},
#    'html_instructions': 'Walk to Kyungbang Time Square, Shinsegae Department Store',
#    'polyline': {'points': 'if~cFqpqeWaLlD'},
#    'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#    'steps': [{'distance': {'text': '0.2 km', 'value': 244},
#      'duration': {'text': '4 mins', 'value': 244},
#      'end_location': {'lat': 37.517505, 'lng': 126.906263},
#      'polyline': {'points': 'if~cFqpqeWaLlD'},
#      'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '4.3 km', 'value': 4332},
#    'duration': {'text': '12 mins', 'value': 715},
#    'end_location': {'lat': 37.538003, 'lng': 126.882083},
#    'html_instructions': 'Bus towards Mokdong',
#    'polyline': {'points': 'ks~cFckqeWACgLvEk@v@c@p@g@xAKpAWzCGl@?BqDhc@?@_@hEORSBgG}@A?qMqBwCe@A?mG_Ae@Aa@Fc@TKXeAzBELKViG`Pg@jCgEl[}DxZMByC[A?oFk@iBPeBl@iD|AiAj@cAAgAwECKy@aDW_@UKc@?WPs@\\i@Nw@Ia@S[EYRrAvFvBjI'},
#    'start_location': {'lat': 37.517505, 'lng': 126.906263},
#    'transit_details': {'arrival_stop': {'location': {'lat': 37.538003,
#       'lng': 126.882083},
#      'name': '월촌중학교.목동1단지'},
#     'arrival_time': {'text': '5:10\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670573429},
#     'departure_stop': {'location': {'lat': 37.517505, 'lng': 126.906263},
#      'name': 'Kyungbang Time Square, Shinsegae Department Store'},
#     'departure_time': {'text': '4:58\u202fPM',
#      'time_zone': 'Asia/Seoul',
#      'value': 1670572714},
#     'headsign': 'Mokdong',
#     'headway': 480,
#     'line': {'agencies': [{'name': '서울특별시버스운송사업조합',
#        'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}],
#      'color': '#0abb0c',
#      'name': '서울 지선버스',
#      'short_name': '6637',
#      'text_color': '#ffffff',
#      'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#       'name': 'Bus',
#       'type': 'BUS'}},
#     'num_stops': 8},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '0.3 km', 'value': 323},
#    'duration': {'text': '5 mins', 'value': 324},
#    'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#    'html_instructions': 'Walk to 20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#    'polyline': {'points': 'osbdF_tleWkF_T'},
#    'start_location': {'lat': 37.538003, 'lng': 126.882083},
#    'steps': [{'distance': {'text': '0.3 km', 'value': 323},
#      'duration': {'text': '5 mins', 'value': 324},
#      'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#      'polyline': {'points': 'osbdF_tleWkF_T'},
#      'start_location': {'lat': 37.538003, 'lng': 126.882083},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'}],
#  'traffic_speed_entry': [],
#  'via_waypoint': []}

# %%
route = route['steps']
route
# Out:
# [{'distance': {'text': '0.9 km', 'value': 868},
#   'duration': {'text': '15 mins', 'value': 872},
#   'end_location': {'lat': 37.238068, 'lng': 127.190282},
#   'html_instructions': 'Walk to Myongji Univ. Station',
#   'polyline': {'points': 'mufbF{fhgWoj@}T?pA'},
#   'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#   'steps': [{'distance': {'text': '0.8 km', 'value': 833},
#     'duration': {'text': '14 mins', 'value': 834},
#     'end_location': {'lat': 37.238069, 'lng': 127.190686},
#     'polyline': {'points': 'mufbF{fhgWoj@}T'},
#     'start_location': {'lat': 37.2311148, 'lng': 127.1871807},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '1 m', 'value': 0},
#     'duration': {'text': '1 min', 'value': 34},
#     'end_location': {'lat': 37.238069, 'lng': 127.190686},
#     'html_instructions': 'Take entrance <span class="location">2</span>',
#     'polyline': {'points': '}`hbFy|hgW'},
#     'start_location': {'lat': 37.238069, 'lng': 127.190686},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '1 m', 'value': 0},
#     'duration': {'text': '1 min', 'value': 0},
#     'end_location': {'lat': 37.238069, 'lng': 127.190686},
#     'polyline': {'points': '}`hbFy|hgW'},
#     'start_location': {'lat': 37.238069, 'lng': 127.190686},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '35 m', 'value': 35},
#     'duration': {'text': '1 min', 'value': 4},
#     'end_location': {'lat': 37.238068, 'lng': 127.190282},
#     'polyline': {'points': '}`hbFy|hgW?pA'},
#     'start_location': {'lat': 37.238069, 'lng': 127.190686},
#     'travel_mode': 'WALKING'}],
#   'travel_mode': 'WALKING'},
#  {'distance': {'text': '10.1 km', 'value': 10059},
#   'duration': {'text': '16 mins', 'value': 960},
#   'end_location': {'lat': 37.275664, 'lng': 127.115956},
#   'html_instructions': 'Subway towards 1701',
#   'polyline': {'points': '}`hbFgzhgWWp@k@zBO|@K|@Eh@GrDIjEItBMvBKrAW~B_@fCkAbJEfAE|@?p@?hADvARbEFnA@v@f@hNFjB@t@?n@El@El@UbAu@nCiCfIyBhHuAlE[t@Yj@sArB[f@Y\\uGzHkAfAk@l@mCdD_@d@QPSPWJWJa@L]Ha@?a@Ga@Oa@Qg@]kAmAmCsCyHiImAeAy@i@aA[]Io@KWE_@Ak@AaADoATo@T]Pg@Zy@n@qBvB}AzAaDvCkCpCgAz@_BdAaEtCkAbAw@`A}B`D_CfDqCtDiCxCe@h@A@]Z}E|D{FjFuCbDiCjCwBtAuIxEaCvAaC|AkCfBeD`CkClBiAbAmArAmAhAaAl@g@XsCpAgBl@}@b@s@b@{@r@i@h@g@v@[r@i@vAUz@Kj@Kx@Gr@Cr@?r@@jADv@H|@Nx@Pt@x@jC?BRv@`AxDnDlNRv@\\dAl@rAx@lAb@b@r@h@fA`@xCn@dCh@`@L^TZ^xAbCzAbDl@lAj@xAd@xAb@zAX|AVdBLlADbAFtA?pA@rAIvAKtAWzA]pBu@dCw@tB_@p@k@~@u@pAsA`C_@t@?@W\\eApAeBpBmBlB_A|@_A`Ay@fA[`@{EdHeE`GQZ[v@Mt@O~AOvBOxCGhACfB@j@e@zC'},
#   'start_location': {'lat': 37.238068, 'lng': 127.190282},
#   'transit_details': {'arrival_stop': {'location': {'lat': 37.275664,
#      'lng': 127.115956},
#     'name': 'Giheung'},
#    'arrival_time': {'text': '3:52\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670568720},
#    'departure_stop': {'location': {'lat': 37.238068, 'lng': 127.190282},
#     'name': 'Myongji Univ. Station'},
#    'departure_time': {'text': '3:36\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670567760},
#    'headsign': '1701',
#    'line': {'agencies': [{'name': '용인경량전철주신회사',
#       'url': 'http://www.ever-line.co.kr/everline/index.php'}],
#     'color': '#5eae53',
#     'name': '수도권전철',
#     'short_name': '용인 경전철',
#     'text_color': '#ffffff',
#     'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#      'name': 'Subway',
#      'type': 'SUBWAY'}},
#    'num_stops': 8},
#   'travel_mode': 'TRANSIT'},
#  {'distance': {'text': '0.1 km', 'value': 106},
#   'duration': {'text': '2 mins', 'value': 107},
#   'end_location': {'lat': 37.275664, 'lng': 127.115956},
#   'html_instructions': 'Walk to Giheung',
#   'polyline': {'points': '{kobFwizfWrAy@sAx@'},
#   'start_location': {'lat': 37.275664, 'lng': 127.115956},
#   'steps': [{'distance': {'text': '1 m', 'value': 0},
#     'duration': {'text': '1 min', 'value': 0},
#     'end_location': {'lat': 37.275664, 'lng': 127.115956},
#     'polyline': {'points': '{kobFwizfW'},
#     'start_location': {'lat': 37.275664, 'lng': 127.115956},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '1 m', 'value': 0},
#     'duration': {'text': '1 min', 'value': 0},
#     'end_location': {'lat': 37.275664, 'lng': 127.115956},
#     'polyline': {'points': '{kobFwizfW'},
#     'start_location': {'lat': 37.275664, 'lng': 127.115956},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '1 m', 'value': 0},
#     'duration': {'text': '1 min', 'value': 0},
#     'end_location': {'lat': 37.275664, 'lng': 127.115956},
#     'polyline': {'points': '{kobFwizfW'},
#     'start_location': {'lat': 37.275664, 'lng': 127.115956},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '1 m', 'value': 0},
#     'duration': {'text': '1 min', 'value': 0},
#     'end_location': {'lat': 37.275664, 'lng': 127.115956},
#     'polyline': {'points': '{kobFwizfW'},
#     'start_location': {'lat': 37.275664, 'lng': 127.115956},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '53 m', 'value': 53},
#     'duration': {'text': '1 min', 'value': 54},
#     'end_location': {'lat': 37.27524, 'lng': 127.116251},
#     'html_instructions': 'Take exit <span class="location">3</span>',
#     'polyline': {'points': '{kobFwizfWrAy@'},
#     'start_location': {'lat': 37.275664, 'lng': 127.115956},
#     'travel_mode': 'WALKING'},
#    {'distance': {'text': '53 m', 'value': 53},
#     'duration': {'text': '1 min', 'value': 53},
#     'end_location': {'lat': 37.275664, 'lng': 127.115956},
#     'polyline': {'points': 'giobFqkzfWsAx@'},
#     'start_location': {'lat': 37.27524, 'lng': 127.116251},
#     'travel_mode': 'WALKING'}],
#   'travel_mode': 'WALKING'},
#  {'distance': {'text': '13.6 km', 'value': 13565},
#   'duration': {'text': '21 mins', 'value': 1260},
#   'end_location': {'lat': 37.266251, 'lng': 127.000034},
#   'html_instructions': 'Subway towards 11109',
#   'polyline': {'points': '{kobFwizfW?@B?vCAxGAvTEbOAxHInA?fBHrCl@z@X|@b@|@z@x@dBl@rAv@~Bv@|C`@zCZxDDtAF`K?@DvDXdEh@jPHpBV~Fl@|Nn@hQJrJKxJS|Gy@|KwDv\\O|AAfBH|AP|AZnBf@pBj@xAn@rAjDxDtDlD?@nDdDdk@ji@@@rBfB`JdIrMxLbAdAb@z@r@pBZdBL|AJnGHjHArJS`HDvFLvFn@hXEjBM|AK|@e@tBcAxBo_@bo@a@p@a@b@}@t@cCbBgIzEmA~@o@r@e@t@c@p@}@pBwBfDmBbB}@`@mAXyJnAs@Xw@`@u@n@k@f@s@dAs@zA_@nAuCjP_G~]cHde@{@~HwA|Jc@bDe@jDS~BWlBy@|Ei@lBkAbDcCnFuAdD_@|Aa@dCOrCAlBD|BTtB\\~AdHhWlApEQJ'},
#   'start_location': {'lat': 37.275664, 'lng': 127.115956},
#   'transit_details': {'arrival_stop': {'location': {'lat': 37.266251,
#      'lng': 127.000034},
#     'name': 'Suwon Station'},
#    'arrival_time': {'text': '4:18\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670570280},
#    'departure_stop': {'location': {'lat': 37.275664, 'lng': 127.115956},
#     'name': 'Giheung'},
#    'departure_time': {'text': '3:57\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670569020},
#    'headsign': '11109',
#    'line': {'agencies': [{'name': '코레일', 'url': 'http://www.odsay.com/'}],
#     'color': '#f2c305',
#     'name': '수도권 전철 수인·분당선',
#     'short_name': '수인.분당선',
#     'text_color': '#000000',
#     'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#      'name': 'Subway',
#      'type': 'SUBWAY'}},
#    'num_stops': 8},
#   'travel_mode': 'TRANSIT'},
#  {'distance': {'text': '28.9 km', 'value': 28900},
#   'duration': {'text': '23 mins', 'value': 1380},
#   'end_location': {'lat': 37.5154133, 'lng': 126.9071288},
#   'html_instructions': 'Train towards To Yongsan',
#   'polyline': {'points': 'opmbF{scfWyto@hbQ'},
#   'start_location': {'lat': 37.2661617, 'lng': 126.9998207},
#   'transit_details': {'arrival_stop': {'location': {'lat': 37.5154133,
#      'lng': 126.9071288},
#     'name': 'Yeongdeungpo'},
#    'arrival_time': {'text': '4:46\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670571960},
#    'departure_stop': {'location': {'lat': 37.2661617, 'lng': 126.9998207},
#     'name': 'Suwon Station'},
#    'departure_time': {'text': '4:23\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670570580},
#    'headsign': 'To Yongsan',
#    'line': {'agencies': [{'name': 'korail',
#       'url': 'https://ga-g.onntapi.com/#1&en'}],
#     'name': 'Honam',
#     'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/rail2.png',
#      'name': 'Train',
#      'type': 'HEAVY_RAIL'}},
#    'num_stops': 1,
#    'trip_short_name': 'Mugunghwa No.1406'},
#   'travel_mode': 'TRANSIT'},
#  {'distance': {'text': '0.2 km', 'value': 244},
#   'duration': {'text': '4 mins', 'value': 244},
#   'end_location': {'lat': 37.517505, 'lng': 126.906263},
#   'html_instructions': 'Walk to Kyungbang Time Square, Shinsegae Department Store',
#   'polyline': {'points': 'if~cFqpqeWaLlD'},
#   'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#   'steps': [{'distance': {'text': '0.2 km', 'value': 244},
#     'duration': {'text': '4 mins', 'value': 244},
#     'end_location': {'lat': 37.517505, 'lng': 126.906263},
#     'polyline': {'points': 'if~cFqpqeWaLlD'},
#     'start_location': {'lat': 37.5154133, 'lng': 126.9071288},
#     'travel_mode': 'WALKING'}],
#   'travel_mode': 'WALKING'},
#  {'distance': {'text': '4.3 km', 'value': 4332},
#   'duration': {'text': '12 mins', 'value': 715},
#   'end_location': {'lat': 37.538003, 'lng': 126.882083},
#   'html_instructions': 'Bus towards Mokdong',
#   'polyline': {'points': 'ks~cFckqeWACgLvEk@v@c@p@g@xAKpAWzCGl@?BqDhc@?@_@hEORSBgG}@A?qMqBwCe@A?mG_Ae@Aa@Fc@TKXeAzBELKViG`Pg@jCgEl[}DxZMByC[A?oFk@iBPeBl@iD|AiAj@cAAgAwECKy@aDW_@UKc@?WPs@\\i@Nw@Ia@S[EYRrAvFvBjI'},
#   'start_location': {'lat': 37.517505, 'lng': 126.906263},
#   'transit_details': {'arrival_stop': {'location': {'lat': 37.538003,
#      'lng': 126.882083},
#     'name': '월촌중학교.목동1단지'},
#    'arrival_time': {'text': '5:10\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670573429},
#    'departure_stop': {'location': {'lat': 37.517505, 'lng': 126.906263},
#     'name': 'Kyungbang Time Square, Shinsegae Department Store'},
#    'departure_time': {'text': '4:58\u202fPM',
#     'time_zone': 'Asia/Seoul',
#     'value': 1670572714},
#    'headsign': 'Mokdong',
#    'headway': 480,
#    'line': {'agencies': [{'name': '서울특별시버스운송사업조합',
#       'url': 'http://www.odsay.com/Bus/Seoul_Main.asp?CID=1000&LMenu=1'}],
#     'color': '#0abb0c',
#     'name': '서울 지선버스',
#     'short_name': '6637',
#     'text_color': '#ffffff',
#     'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#      'name': 'Bus',
#      'type': 'BUS'}},
#    'num_stops': 8},
#   'travel_mode': 'TRANSIT'},
#  {'distance': {'text': '0.3 km', 'value': 323},
#   'duration': {'text': '5 mins', 'value': 324},
#   'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#   'html_instructions': 'Walk to 20 Mokdongseo-ro, Mok-dong, Yangcheon-gu, Seoul, South Korea',
#   'polyline': {'points': 'osbdF_tleWkF_T'},
#   'start_location': {'lat': 37.538003, 'lng': 126.882083},
#   'steps': [{'distance': {'text': '0.3 km', 'value': 323},
#     'duration': {'text': '5 mins', 'value': 324},
#     'end_location': {'lat': 37.5391786, 'lng': 126.8854361},
#     'polyline': {'points': 'osbdF_tleWkF_T'},
#     'start_location': {'lat': 37.538003, 'lng': 126.882083},
#     'travel_mode': 'WALKING'}],
#   'travel_mode': 'WALKING'}]

# %%
cost = route[0]['duration']

# %%
route[1]
# Out:
# {'distance': {'text': '10.1 km', 'value': 10059},
#  'duration': {'text': '16 mins', 'value': 960},
#  'end_location': {'lat': 37.275664, 'lng': 127.115956},
#  'html_instructions': 'Subway towards 1701',
#  'polyline': {'points': '}`hbFgzhgWWp@k@zBO|@K|@Eh@GrDIjEItBMvBKrAW~B_@fCkAbJEfAE|@?p@?hADvARbEFnA@v@f@hNFjB@t@?n@El@El@UbAu@nCiCfIyBhHuAlE[t@Yj@sArB[f@Y\\uGzHkAfAk@l@mCdD_@d@QPSPWJWJa@L]Ha@?a@Ga@Oa@Qg@]kAmAmCsCyHiImAeAy@i@aA[]Io@KWE_@Ak@AaADoATo@T]Pg@Zy@n@qBvB}AzAaDvCkCpCgAz@_BdAaEtCkAbAw@`A}B`D_CfDqCtDiCxCe@h@A@]Z}E|D{FjFuCbDiCjCwBtAuIxEaCvAaC|AkCfBeD`CkClBiAbAmArAmAhAaAl@g@XsCpAgBl@}@b@s@b@{@r@i@h@g@v@[r@i@vAUz@Kj@Kx@Gr@Cr@?r@@jADv@H|@Nx@Pt@x@jC?BRv@`AxDnDlNRv@\\dAl@rAx@lAb@b@r@h@fA`@xCn@dCh@`@L^TZ^xAbCzAbDl@lAj@xAd@xAb@zAX|AVdBLlADbAFtA?pA@rAIvAKtAWzA]pBu@dCw@tB_@p@k@~@u@pAsA`C_@t@?@W\\eApAeBpBmBlB_A|@_A`Ay@fA[`@{EdHeE`GQZ[v@Mt@O~AOvBOxCGhACfB@j@e@zC'},
#  'start_location': {'lat': 37.238068, 'lng': 127.190282},
#  'transit_details': {'arrival_stop': {'location': {'lat': 37.275664,
#     'lng': 127.115956},
#    'name': 'Giheung'},
#   'arrival_time': {'text': '3:52\u202fPM',
#    'time_zone': 'Asia/Seoul',
#    'value': 1670568720},
#   'departure_stop': {'location': {'lat': 37.238068, 'lng': 127.190282},
#    'name': 'Myongji Univ. Station'},
#   'departure_time': {'text': '3:36\u202fPM',
#    'time_zone': 'Asia/Seoul',
#    'value': 1670567760},
#   'headsign': '1701',
#   'line': {'agencies': [{'name': '용인경량전철주신회사',
#      'url': 'http://www.ever-line.co.kr/everline/index.php'}],
#    'color': '#5eae53',
#    'name': '수도권전철',
#    'short_name': '용인 경전철',
#    'text_color': '#ffffff',
#    'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#     'name': 'Subway',
#     'type': 'SUBWAY'}},
#   'num_stops': 8},
#  'travel_mode': 'TRANSIT'}

# %%
route[2]
# Out:
# {'distance': {'text': '0.1 km', 'value': 106},
#  'duration': {'text': '2 mins', 'value': 107},
#  'end_location': {'lat': 37.275664, 'lng': 127.115956},
#  'html_instructions': 'Walk to Giheung',
#  'polyline': {'points': '{kobFwizfWrAy@sAx@'},
#  'start_location': {'lat': 37.275664, 'lng': 127.115956},
#  'steps': [{'distance': {'text': '1 m', 'value': 0},
#    'duration': {'text': '1 min', 'value': 0},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'polyline': {'points': '{kobFwizfW'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '1 m', 'value': 0},
#    'duration': {'text': '1 min', 'value': 0},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'polyline': {'points': '{kobFwizfW'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '1 m', 'value': 0},
#    'duration': {'text': '1 min', 'value': 0},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'polyline': {'points': '{kobFwizfW'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '1 m', 'value': 0},
#    'duration': {'text': '1 min', 'value': 0},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'polyline': {'points': '{kobFwizfW'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '53 m', 'value': 53},
#    'duration': {'text': '1 min', 'value': 54},
#    'end_location': {'lat': 37.27524, 'lng': 127.116251},
#    'html_instructions': 'Take exit <span class="location">3</span>',
#    'polyline': {'points': '{kobFwizfWrAy@'},
#    'start_location': {'lat': 37.275664, 'lng': 127.115956},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '53 m', 'value': 53},
#    'duration': {'text': '1 min', 'value': 53},
#    'end_location': {'lat': 37.275664, 'lng': 127.115956},
#    'polyline': {'points': 'giobFqkzfWsAx@'},
#    'start_location': {'lat': 37.27524, 'lng': 127.116251},
#    'travel_mode': 'WALKING'}],
#  'travel_mode': 'WALKING'}

# %%
lat_lng = []
for i in range(len(route)):
    if route[i]['travel_mode'] == 'WALKING':
        print(route[i]['distance'], route[i]['start_location'], route[i]['end_location'])
        lat_lng.append(route[i]['start_location'])

print(lat_lng)
print(len(lat_lng))
lat_lng[2]
# Out:
# {'text': '0.9 km', 'value': 868} {'lat': 37.2311148, 'lng': 127.1871807} {'lat': 37.238068, 'lng': 127.190282}
# {'text': '0.1 km', 'value': 106} {'lat': 37.275664, 'lng': 127.115956} {'lat': 37.275664, 'lng': 127.115956}
# {'text': '0.2 km', 'value': 244} {'lat': 37.5154133, 'lng': 126.9071288} {'lat': 37.517505, 'lng': 126.906263}
# {'text': '0.3 km', 'value': 323} {'lat': 37.538003, 'lng': 126.882083} {'lat': 37.5391786, 'lng': 126.8854361}
# [{'lat': 37.2311148, 'lng': 127.1871807}, {'lat': 37.275664, 'lng': 127.115956}, {'lat': 37.5154133, 'lng': 126.9071288}, {'lat': 37.538003, 'lng': 126.882083}]
# 4
# {'lat': 37.5154133, 'lng': 126.9071288}

# %%
import requests
import pprint
from bs4 import BeautifulSoup
from datetime import date

part = 'hourly,minutely'
service_key = '36afa2e28efc2803bc05866ef6460430'
today = str(date.today()).replace('-', '')

weather = []

for i in range(len(lat_lng)):
    lat = lat_lng[i]['lat']
    lng = lat_lng[i]['lng']

    params = f'lat={lat}&lon={lon}&units=metric&exclude={part}&lang=kr&appid={service_key}'
    url = 'https://api.openweathermap.org/data/3.0/onecall?' + params

    res = requests.get(url)
    if res.status_code == 200:
        data = res.json()
        #pprint.pprint(data)

        weather.append(data)


    else:
        print("Error Code", res.status_code)

# %%
weather[0]['daily'][0]['weather'][0]['description'] # weather[0~4]daily[0~7]
weather[0]['current']['weather'][0]['description']
# Out:
# '약간의 구름이 낀 하늘'

# %%
desc = []
for p in range(len(weather)):
    for q in range(8):
        weather_ = weather[p]['daily'][q]['weather'][0]['description']
        desc.append(weather_)

# %%
lat_lng
# Out:
# [{'lat': 37.2311148, 'lng': 127.1871807},
#  {'lat': 37.275664, 'lng': 127.115956},
#  {'lat': 37.5154133, 'lng': 126.9071288},
#  {'lat': 37.538003, 'lng': 126.882083}]

# %%
day_after = []
for i in range(8):
    daily = data['daily'][i]['weather'][0]['description']
    if daily == "비":
        day_after.append(i)
    elif daily == "눈":
        day_after.append(i)

# %%
if __name__ == '__main__':
    with SSHTunnelForwarder(('seumchae.iptime.org', 8022),
                            ssh_username='capstone',
                            ssh_password='capstone2022',
                            remote_bind_address=('127.0.0.1', 3306)) as tunnel:
        with pymysql.connect(host='127.0.0.1', user='root', password='capstone2022', port=tunnel.local_bind_port,
                             db='Capstone', charset="utf8", cursorclass=pymysql.cursors.DictCursor) as conn:
            with conn.cursor() as cur:

                sql = 'select lat,lon from client where name = %s;'
                cur.execute(sql, ('seum'))
                results = cur.fetchall()
                for result in results:
                    print(result)
    print('\nfinish!\n', '-----' * 20)
# Out:
# finish!
#  ----------------------------------------------------------------------------------------------------

# %%
from datetime import datetime
now = datetime.now()
print(now)
import urllib.request, json
def transit_route(origin_lat, origin_lon, destination_lat,destination_lon):
    #Google MapsDdirections API endpoint
    endpoint = "https://maps.googleapis.com/maps/api/directions/json?"
    api_key= "AIzaSyBRRvsR_jj8_NajJiFRcIBl3_Hc-3eicOA"
    nav_request = 'origin={},{}&destination={},{}&mode=transit&transit_routing_preference=fewer_transfers&key={}'.format(origin_lat, origin_lon, destination_lat ,destination_lon,api_key)
    request = endpoint + nav_request
    #Sends the request and reads the response.
    response = urllib.request.urlopen(request).read()
    #Loads response as JSON
    directions = json.loads(response)
    return directions
# Out:
# 2022-12-09 15:02:58.531886

# %%
def executeSql(cmd):
    if __name__ == '__main__':
        with SSHTunnelForwarder(('seumchae.iptime.org', 8022),
                                ssh_username='capstone',
                                ssh_password='capstone2022',
                                remote_bind_address=('127.0.0.1', 3306)) as tunnel:
            with pymysql.connect(host='127.0.0.1', user='root', password='capstone2022', port=tunnel.local_bind_port,
                                 db='Capstone', charset="utf8", cursorclass=pymysql.cursors.DictCursor) as conn:
                with conn.cursor() as cur:

                    sql = cmd
                    cur.execute(sql)
                    results = cur.fetchall()
                    schedule = []
                    for result in results:

                        schedule.append(result)
    return result

# %%
from geopy.geocoders import Nominatim
from datetime import datetime

geo_local = Nominatim(user_agent = 'South Korea')
reg_beg = '용인시 처인구 역북동 명지로60번길 8-3'
reg_fin = '서울시 양천구 목동 목동서로 155'
def geocoding(address):
    
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y
    
    except :
        return [0,0]
lon_beg = geocoding(reg_beg)[1]
lat_beg = geocoding(reg_beg)[0]
lon_fin = geocoding(reg_fin)[1]
lat_fin = geocoding(reg_fin)[0]
print(reg_beg)
print(lat_beg, lon_beg)
print(reg_fin)
print(lat_fin, lon_fin)
lon_beg = str(lon_beg)
lat_beg = str(lat_beg)
lon_fin = str(lon_fin)
lat_fin = str(lat_fin)


now = datetime.now()
print(now)
import urllib.request, json
def transit_route(origin_lat, origin_lon, destination_lat,destination_lon):
    #Google MapsDdirections API endpoint
    endpoint = "https://maps.googleapis.com/maps/api/directions/json?"
    api_key= "AIzaSyBRRvsR_jj8_NajJiFRcIBl3_Hc-3eicOA"
    nav_request = 'origin={},{}&destination={},{}&mode=transit&transit_routing_preference=fewer_transfers&key={}'.format(origin_lat, origin_lon, destination_lat ,destination_lon,api_key)
    request = endpoint + nav_request
    #Sends the request and reads the response.
    response = urllib.request.urlopen(request).read()
    #Loads response as JSON
    directions = json.loads(response)
    return directions

#경유지 탐색
def findaway(lat_beg, lon_beg, lat_fin, lon_fin):
    cord_list = []
    way = transit_route(lat_beg, lon_beg ,lat_fin, lon_fin)['routes'][0]['legs'][0]['steps']
    for i in range(len(way)):
        if way[i]['travel_mode'] == 'WALKING':
            cord_list.append(way[i]['start_location'])
    part = 'hourly,minutely'
    service_key = '36afa2e28efc2803bc05866ef6460430'
    today = str(date.today()).replace('-', '')

    weather = []

    for i in range(len(cord_list)):
        lat = cord_list[i]['lat']
        lng = cord_list[i]['lng']

        params = f'lat={lat}&lon={lon}&units=metric&exclude={part}&lang=kr&appid={service_key}'
        url = 'https://api.openweathermap.org/data/3.0/onecall?' + params

        res = requests.get(url)
        if res.status_code == 200:
            data = res.json()
            #pprint.pprint(data)

            weather.append(data)
        else:
            print("Error Code", res.status_code)
    desc = []
    for p in range(len(weather)):
        for q in range(8):
            weather_ = weather[p]['daily'][q]['weather'][0]['description']
            desc.append(weather_)





    return cord_list, desc
findaway(result['lat'], result['lon'], lat_fin, lon_fin)

def setWeather(isGroup, num):
    if isGroup == True:
        #그룹날씨 업데이트
        print()
    else:
        dst = executeSql('select lat, lon from schedule where num = ' + str(num))
        stt = executeSql('select lat, lon from client where email =(select email from schedule where num = {})'.format(str(num)))
        print(dst)
        print(stt)
        print(dst[0])


        
setWeather(False,'11')
# Out:
# 용인시 처인구 역북동 명지로60번길 8-3
# 37.2311148 127.1871807
# 서울시 양천구 목동 목동서로 155
# 37.5391786 126.8854361
# 2022-12-09 15:03:37.827258
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_463182/2333860014.py in <module>
#      82
#      83     return cord_list, desc
# ---> 84 findaway(result['lat'], result['lon'], lat_fin, lon_fin)
#      85
#      86 def setWeather(isGroup, num):
#
# NameError: name 'result' is not defined

# %%
def setWeather(isGroup, num):
    if isGroup == True:
        #그룹날씨 업데이트
        print()
    else:
        dst = executeSql('select lat, lon from schedule where num = ' + str(num))
        stt = executeSql('select lat, lon from client where email =(select email from schedule where num = {})'.format(str(num)))
        return [stt['lat'], stt['lon'], dst['lat'], dst['lon']]


        
setWeather(False,'11')

# %%
def findaway(reg):
    lat_beg, lon_beg, lat_fin, lon_fin = reg
    cord_list = []
    
    way = transit_route(lat_beg, lon_beg ,lat_fin, lon_fin)['routes'][0]['legs'][0]['steps']

    for i in range(len(way)):
        if way[i]['travel_mode'] == 'WALKING':
            cord_list.append(way[i]['start_location'])
    part = 'hourly,minutely'
    service_key = '36afa2e28efc2803bc05866ef6460430'
    today = str(date.today()).replace('-', '')

    weather = []

    for i in range(len(cord_list)):
        lat = cord_list[i]['lat']
        lng = cord_list[i]['lng']

        params = f'lat={lat}&lon={lon}&units=metric&exclude={part}&lang=kr&appid={service_key}'
        url = 'https://api.openweathermap.org/data/3.0/onecall?' + params

        res = requests.get(url)
        if res.status_code == 200:
            data = res.json()
            #pprint.pprint(data)

            weather.append(data)
        else:
            print("Error Code", res.status_code)
    desc = []
    for p in range(len(weather)):
        for q in range(8):
            weather_ = weather[p]['daily'][q]['weather'][0]['id']
            desc.append(weather_)
    return cord_list, desc
findaway(setWeather(False, '11'))

# %%
def
