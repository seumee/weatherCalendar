# %%
import requests
import pprint
from bs4 import BeautifulSoup
from datetime import date

today = str(date.today()).replace('-', '')
lat = '37.22171000000002'
lon = '127.18147255393642'
part = 'hourly,minutely'
today
service_key = '36afa2e28efc2803bc05866ef6460430'
params = f'lat={lat}&lon={lon}&units=metric&exclude={part}&lang=kr&appid={service_key}'
url = 'https://api.openweathermap.org/data/3.0/onecall?' + params

res = requests.get(url)



if res.status_code == 200:
    data = res.json()
    pprint.pprint(data)
else:
    print("Error Code", res.status_code)
# Out:
# {'current': {'clouds': 0,
#              'dew_point': -2.79,
#              'dt': 1665991869,
#              'feels_like': 11.37,
#              'humidity': 32,
#              'pressure': 1019,
#              'sunrise': 1665956416,
#              'sunset': 1665996771,
#              'temp': 13.16,
#              'uvi': 0.32,
#              'visibility': 10000,
#              'weather': [{'description': '맑음',
#                           'icon': '01d',
#                           'id': 800,
#                           'main': 'Clear'}],
#              'wind_deg': 320,
#              'wind_gust': 10.29,
#              'wind_speed': 7.72},
#  'daily': [{'clouds': 0,
#             'dew_point': -9.86,
#             'dt': 1665975600,
#             'feels_like': {'day': 10.57,
#                            'eve': 10.73,
#                            'morn': 8.7,
#                            'night': 5.81},
#             'humidity': 19,
#             'moon_phase': 0.73,
#             'moonrise': 1666015260,
#             'moonset': 1665981600,
#             'pop': 0,
#             'pressure': 1020,
#             'sunrise': 1665956416,
#             'sunset': 1665996771,
#             'temp': {'day': 12.74,
#                      'eve': 12.53,
#                      'max': 14.02,
#                      'min': 8.01,
#                      'morn': 10.38,
#                      'night': 8.01},
#             'uvi': 4.44,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 296,
#             'wind_gust': 10.11,
#             'wind_speed': 6.62},
#            {'clouds': 0,
#             'dew_point': -5.7,
#             'dt': 1666062000,
#             'feels_like': {'day': 9.68,
#                            'eve': 8.3,
#                            'morn': 4.37,
#                            'night': 6.79},
#             'humidity': 29,
#             'moon_phase': 0.75,
#             'moonrise': 1666105200,
#             'moonset': 1666070520,
#             'pop': 0,
#             'pressure': 1023,
#             'sunrise': 1666042872,
#             'sunset': 1666083091,
#             'temp': {'day': 11.7,
#                      'eve': 10.23,
#                      'max': 12.71,
#                      'min': 6.01,
#                      'morn': 6.12,
#                      'night': 8.04},
#             'uvi': 4.08,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 302,
#             'wind_gust': 7.89,
#             'wind_speed': 4.23},
#            {'clouds': 0,
#             'dew_point': -6.2,
#             'dt': 1666148400,
#             'feels_like': {'day': 11.68,
#                            'eve': 10.05,
#                            'morn': 6.16,
#                            'night': 9.48},
#             'humidity': 24,
#             'moon_phase': 0.79,
#             'moonrise': 0,
#             'moonset': 1666159080,
#             'pop': 0,
#             'pressure': 1026,
#             'sunrise': 1666129329,
#             'sunset': 1666169411,
#             'temp': {'day': 13.63,
#                      'eve': 11.99,
#                      'max': 15.12,
#                      'min': 6.04,
#                      'morn': 6.16,
#                      'night': 9.48},
#             'uvi': 3.92,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 319,
#             'wind_gust': 4.94,
#             'wind_speed': 3.62},
#            {'clouds': 3,
#             'dew_point': -0.79,
#             'dt': 1666234800,
#             'feels_like': {'day': 14.36,
#                            'eve': 12.27,
#                            'morn': 6.76,
#                            'night': 10.66},
#             'humidity': 31,
#             'moon_phase': 0.82,
#             'moonrise': 1666195200,
#             'moonset': 1666247340,
#             'pop': 0,
#             'pressure': 1028,
#             'sunrise': 1666215786,
#             'sunset': 1666255732,
#             'temp': {'day': 15.9,
#                      'eve': 13.84,
#                      'max': 17.77,
#                      'min': 6.76,
#                      'morn': 6.76,
#                      'night': 12.04},
#             'uvi': 4.32,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 313,
#             'wind_gust': 2.76,
#             'wind_speed': 2.25},
#            {'clouds': 100,
#             'dew_point': 3.35,
#             'dt': 1666321200,
#             'feels_like': {'day': 15.13,
#                            'eve': 12.97,
#                            'morn': 9.18,
#                            'night': 11.73},
#             'humidity': 41,
#             'moon_phase': 0.85,
#             'moonrise': 1666285320,
#             'moonset': 1666335420,
#             'pop': 0,
#             'pressure': 1025,
#             'sunrise': 1666302244,
#             'sunset': 1666342054,
#             'temp': {'day': 16.37,
#                      'eve': 14.38,
#                      'max': 17.29,
#                      'min': 10.46,
#                      'morn': 10.46,
#                      'night': 13.11},
#             'uvi': 4.3,
#             'weather': [{'description': '온흐림',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 257,
#             'wind_gust': 2.97,
#             'wind_speed': 2.69},
#            {'clouds': 39,
#             'dew_point': 3.01,
#             'dt': 1666407600,
#             'feels_like': {'day': 16.81,
#                            'eve': 15.08,
#                            'morn': 9.74,
#                            'night': 13.58},
#             'humidity': 36,
#             'moon_phase': 0.89,
#             'moonrise': 1666375440,
#             'moonset': 1666423320,
#             'pop': 0,
#             'pressure': 1020,
#             'sunrise': 1666388702,
#             'sunset': 1666428378,
#             'temp': {'day': 18.01,
#                      'eve': 16.01,
#                      'max': 19.45,
#                      'min': 11.28,
#                      'morn': 11.28,
#                      'night': 14.27},
#             'uvi': 5,
#             'weather': [{'description': '구름조금',
#                          'icon': '03d',
#                          'id': 802,
#                          'main': 'Clouds'}],
#             'wind_deg': 281,
#             'wind_gust': 4,
#             'wind_speed': 2.24},
#            {'clouds': 0,
#             'dew_point': 0.86,
#             'dt': 1666494000,
#             'feels_like': {'day': 16.79,
#                            'eve': 14.37,
#                            'morn': 11.02,
#                            'night': 12.42},
#             'humidity': 30,
#             'moon_phase': 0.92,
#             'moonrise': 1666465560,
#             'moonset': 1666511220,
#             'pop': 0,
#             'pressure': 1020,
#             'sunrise': 1666475161,
#             'sunset': 1666514702,
#             'temp': {'day': 18.14,
#                      'eve': 15.72,
#                      'max': 19.19,
#                      'min': 11.49,
#                      'morn': 11.49,
#                      'night': 13.71},
#             'uvi': 5,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 308,
#             'wind_gust': 4.32,
#             'wind_speed': 3.13},
#            {'clouds': 0,
#             'dew_point': 6.72,
#             'dt': 1666580400,
#             'feels_like': {'day': 15.81,
#                            'eve': 13.77,
#                            'morn': 9.53,
#                            'night': 11.98},
#             'humidity': 50,
#             'moon_phase': 0.95,
#             'moonrise': 1666555800,
#             'moonset': 1666599120,
#             'pop': 0,
#             'pressure': 1021,
#             'sunrise': 1666561619,
#             'sunset': 1666601027,
#             'temp': {'day': 16.77,
#                      'eve': 15.01,
#                      'max': 18.38,
#                      'min': 9.53,
#                      'morn': 9.53,
#                      'night': 13.27},
#             'uvi': 5,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 257,
#             'wind_gust': 2.42,
#             'wind_speed': 1.64}],
#  'lat': 37.2217,
#  'lon': 127.1815,
#  'timezone': 'Asia/Seoul',
#  'timezone_offset': 32400}

# %%
data
# Out:
# {'lat': 37.2217,
#  'lon': 127.1815,
#  'timezone': 'Asia/Seoul',
#  'timezone_offset': 32400,
#  'current': {'dt': 1665991869,
#   'sunrise': 1665956416,
#   'sunset': 1665996771,
#   'temp': 13.16,
#   'feels_like': 11.37,
#   'pressure': 1019,
#   'humidity': 32,
#   'dew_point': -2.79,
#   'uvi': 0.32,
#   'clouds': 0,
#   'visibility': 10000,
#   'wind_speed': 7.72,
#   'wind_deg': 320,
#   'wind_gust': 10.29,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01d'}]},
#  'daily': [{'dt': 1665975600,
#    'sunrise': 1665956416,
#    'sunset': 1665996771,
#    'moonrise': 1666015260,
#    'moonset': 1665981600,
#    'moon_phase': 0.73,
#    'temp': {'day': 12.74,
#     'min': 8.01,
#     'max': 14.02,
#     'night': 8.01,
#     'eve': 12.53,
#     'morn': 10.38},
#    'feels_like': {'day': 10.57, 'night': 5.81, 'eve': 10.73, 'morn': 8.7},
#    'pressure': 1020,
#    'humidity': 19,
#    'dew_point': -9.86,
#    'wind_speed': 6.62,
#    'wind_deg': 296,
#    'wind_gust': 10.11,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 4.44},
#   {'dt': 1666062000,
#    'sunrise': 1666042872,
#    'sunset': 1666083091,
#    'moonrise': 1666105200,
#    'moonset': 1666070520,
#    'moon_phase': 0.75,
#    'temp': {'day': 11.7,
#     'min': 6.01,
#     'max': 12.71,
#     'night': 8.04,
#     'eve': 10.23,
#     'morn': 6.12},
#    'feels_like': {'day': 9.68, 'night': 6.79, 'eve': 8.3, 'morn': 4.37},
#    'pressure': 1023,
#    'humidity': 29,
#    'dew_point': -5.7,
#    'wind_speed': 4.23,
#    'wind_deg': 302,
#    'wind_gust': 7.89,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 4.08},
#   {'dt': 1666148400,
#    'sunrise': 1666129329,
#    'sunset': 1666169411,
#    'moonrise': 0,
#    'moonset': 1666159080,
#    'moon_phase': 0.79,
#    'temp': {'day': 13.63,
#     'min': 6.04,
#     'max': 15.12,
#     'night': 9.48,
#     'eve': 11.99,
#     'morn': 6.16},
#    'feels_like': {'day': 11.68, 'night': 9.48, 'eve': 10.05, 'morn': 6.16},
#    'pressure': 1026,
#    'humidity': 24,
#    'dew_point': -6.2,
#    'wind_speed': 3.62,
#    'wind_deg': 319,
#    'wind_gust': 4.94,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 3.92},
#   {'dt': 1666234800,
#    'sunrise': 1666215786,
#    'sunset': 1666255732,
#    'moonrise': 1666195200,
#    'moonset': 1666247340,
#    'moon_phase': 0.82,
#    'temp': {'day': 15.9,
#     'min': 6.76,
#     'max': 17.77,
#     'night': 12.04,
#     'eve': 13.84,
#     'morn': 6.76},
#    'feels_like': {'day': 14.36, 'night': 10.66, 'eve': 12.27, 'morn': 6.76},
#    'pressure': 1028,
#    'humidity': 31,
#    'dew_point': -0.79,
#    'wind_speed': 2.25,
#    'wind_deg': 313,
#    'wind_gust': 2.76,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 3,
#    'pop': 0,
#    'uvi': 4.32},
#   {'dt': 1666321200,
#    'sunrise': 1666302244,
#    'sunset': 1666342054,
#    'moonrise': 1666285320,
#    'moonset': 1666335420,
#    'moon_phase': 0.85,
#    'temp': {'day': 16.37,
#     'min': 10.46,
#     'max': 17.29,
#     'night': 13.11,
#     'eve': 14.38,
#     'morn': 10.46},
#    'feels_like': {'day': 15.13, 'night': 11.73, 'eve': 12.97, 'morn': 9.18},
#    'pressure': 1025,
#    'humidity': 41,
#    'dew_point': 3.35,
#    'wind_speed': 2.69,
#    'wind_deg': 257,
#    'wind_gust': 2.97,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': '온흐림',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 4.3},
#   {'dt': 1666407600,
#    'sunrise': 1666388702,
#    'sunset': 1666428378,
#    'moonrise': 1666375440,
#    'moonset': 1666423320,
#    'moon_phase': 0.89,
#    'temp': {'day': 18.01,
#     'min': 11.28,
#     'max': 19.45,
#     'night': 14.27,
#     'eve': 16.01,
#     'morn': 11.28},
#    'feels_like': {'day': 16.81, 'night': 13.58, 'eve': 15.08, 'morn': 9.74},
#    'pressure': 1020,
#    'humidity': 36,
#    'dew_point': 3.01,
#    'wind_speed': 2.24,
#    'wind_deg': 281,
#    'wind_gust': 4,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': '구름조금',
#      'icon': '03d'}],
#    'clouds': 39,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1666494000,
#    'sunrise': 1666475161,
#    'sunset': 1666514702,
#    'moonrise': 1666465560,
#    'moonset': 1666511220,
#    'moon_phase': 0.92,
#    'temp': {'day': 18.14,
#     'min': 11.49,
#     'max': 19.19,
#     'night': 13.71,
#     'eve': 15.72,
#     'morn': 11.49},
#    'feels_like': {'day': 16.79, 'night': 12.42, 'eve': 14.37, 'morn': 11.02},
#    'pressure': 1020,
#    'humidity': 30,
#    'dew_point': 0.86,
#    'wind_speed': 3.13,
#    'wind_deg': 308,
#    'wind_gust': 4.32,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5},
#   {'dt': 1666580400,
#    'sunrise': 1666561619,
#    'sunset': 1666601027,
#    'moonrise': 1666555800,
#    'moonset': 1666599120,
#    'moon_phase': 0.95,
#    'temp': {'day': 16.77,
#     'min': 9.53,
#     'max': 18.38,
#     'night': 13.27,
#     'eve': 15.01,
#     'morn': 9.53},
#    'feels_like': {'day': 15.81, 'night': 11.98, 'eve': 13.77, 'morn': 9.53},
#    'pressure': 1021,
#    'humidity': 50,
#    'dew_point': 6.72,
#    'wind_speed': 1.64,
#    'wind_deg': 257,
#    'wind_gust': 2.42,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': '맑음',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5}]}

# %%
daily = data['daily'][0]['weather'][0]['description']

# %%
for i in range(8):
    daily = data['daily'][i]['weather'][0]['description']
    print(daily)
# Out:
# 맑음
# 맑음
# 맑음
# 맑음
# 온흐림
# 구름조금
# 맑음
# 맑음

# %%
from datetime import datetime, timedelta
import time
temp = data['daily'][0]['temp']
temp_night = temp['night']
temp_morn = temp['morn']

for j in range(8):
    now = datetime.now()
    date = now + timedelta(days = j + 1)
    daliy = daily = data['daily'][j]['weather'][0]['description']    
    temp = data['daily'][j]['temp']
    temp_morn = temp['morn']
    temp_night = temp['night']
    print(date.strftime('%Y%m%d'), daily, temp_morn, temp_night)
# Out:
# 20221018 맑음 10.38 8.01
# 20221019 맑음 6.12 8.04
# 20221020 맑음 6.16 9.48
# 20221021 맑음 6.76 12.04
# 20221022 온흐림 10.46 13.11
# 20221023 구름조금 11.28 14.27
# 20221024 맑음 11.49 13.71
# 20221025 맑음 9.53 13.27

# %% [markdown]
# # Module Imports
# import mariadb
# import sys
#
# # Connect to MariaDB Platform
# try:
#     conn = mariadb.connect(
#         user="db_user",
#         password="db_user_passwd",
#         host="192.0.2.1",
#         port=3306,
#         database="employees"
#
#     )
# except mariadb.Error as e:
#     print(f"Error connecting to MariaDB Platform: {e}")
#     sys.exit(1)
#
# # Get Cursor
# cur = conn.cursor()

# %%
import requests
import pprint
from bs4 import BeautifulSoup
from datetime import date
from datetime import datetime, timedelta
import time

today = str(date.today()).replace('-', '')
lat = '37.22171000000002'
lon = '127.18147255393642'
part = 'hourly,minutely'
today
service_key = '36afa2e28efc2803bc05866ef6460430'
params = f'lat={lat}&lon={lon}&units=metric&exclude={part}&lang=kr&appid={service_key}'
url = 'https://api.openweathermap.org/data/3.0/onecall?' + params

res = requests.get(url)



if res.status_code == 200:
    data = res.json()
    pprint.pprint(data)
else:
    print("Error Code", res.status_code)

temp = data['daily'][0]['temp']
temp_night = temp['night']
temp_morn = temp['morn']

for j in range(8):
    now = datetime.now()
    date = now + timedelta(days = j + 1)
    daliy = daily = data['daily'][j]['weather'][0]['description']    
    temp = data['daily'][j]['temp']
    temp_morn = temp['morn']
    temp_night = temp['night']
    print(date.strftime('%Y%m%d'), daily, temp_morn, temp_night)
# Out:
# {'current': {'clouds': 0,
#              'dew_point': -13.17,
#              'dt': 1669884589,
#              'feels_like': -6.01,
#              'humidity': 41,
#              'pressure': 1030,
#              'sunrise': 1669847168,
#              'sunset': 1669882470,
#              'temp': -2.98,
#              'uvi': 0,
#              'visibility': 10000,
#              'weather': [{'description': '맑음',
#                           'icon': '01n',
#                           'id': 800,
#                           'main': 'Clear'}],
#              'wind_deg': 340,
#              'wind_speed': 2.06},
#  'daily': [{'clouds': 6,
#             'dew_point': -16.23,
#             'dt': 1669863600,
#             'feels_like': {'day': -7.32,
#                            'eve': -7.8,
#                            'morn': -12.12,
#                            'night': -8.92},
#             'humidity': 35,
#             'moon_phase': 0.27,
#             'moonrise': 1669869480,
#             'moonset': 1669820460,
#             'pop': 0.14,
#             'pressure': 1032,
#             'sunrise': 1669847168,
#             'sunset': 1669882470,
#             'temp': {'day': -3.33,
#                      'eve': -2.98,
#                      'max': -2.58,
#                      'min': -6.54,
#                      'morn': -6.54,
#                      'night': -4.56},
#             'uvi': 1.82,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 329,
#             'wind_gust': 8.88,
#             'wind_speed': 4.56},
#            {'clouds': 1,
#             'dew_point': -18.79,
#             'dt': 1669950000,
#             'feels_like': {'day': -1.73,
#                            'eve': -1.81,
#                            'morn': -7.29,
#                            'night': -4.45},
#             'humidity': 25,
#             'moon_phase': 0.3,
#             'moonrise': 1669957440,
#             'moonset': 1669910940,
#             'pop': 0.11,
#             'pressure': 1032,
#             'sunrise': 1669933624,
#             'sunset': 1669968858,
#             'temp': {'day': -1.73,
#                      'eve': -1.81,
#                      'max': -0.75,
#                      'min': -5.08,
#                      'morn': -4.99,
#                      'night': -2.33},
#             'uvi': 1.8,
#             'weather': [{'description': '맑음',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 339,
#             'wind_gust': 5.43,
#             'wind_speed': 2.9},
#            {'clouds': 100,
#             'dew_point': -1.61,
#             'dt': 1670036400,
#             'feels_like': {'day': -0.83,
#                            'eve': 1.07,
#                            'morn': -4.23,
#                            'night': -6.63},
#             'humidity': 92,
#             'moon_phase': 0.34,
#             'moonrise': 1670045340,
#             'moonset': 1670001300,
#             'pop': 0.77,
#             'pressure': 1026,
#             'snow': 1.65,
#             'sunrise': 1670020080,
#             'sunset': 1670055249,
#             'temp': {'day': -0.83,
#                      'eve': 1.07,
#                      'max': 1.34,
#                      'min': -2.34,
#                      'morn': -1.85,
#                      'night': -1.85},
#             'uvi': 1.02,
#             'weather': [{'description': '눈',
#                          'icon': '13d',
#                          'id': 601,
#                          'main': 'Snow'}],
#             'wind_deg': 309,
#             'wind_gust': 8.54,
#             'wind_speed': 4.1},
#            {'clouds': 97,
#             'dew_point': -18.3,
#             'dt': 1670122800,
#             'feels_like': {'day': -4.74,
#                            'eve': -5.84,
#                            'morn': -8.35,
#                            'night': -6.54},
#             'humidity': 25,
#             'moon_phase': 0.37,
#             'moonrise': 1670133240,
#             'moonset': 1670091540,
#             'pop': 0.25,
#             'pressure': 1031,
#             'sunrise': 1670106534,
#             'sunset': 1670141641,
#             'temp': {'day': -1.33,
#                      'eve': -2.39,
#                      'max': -1.09,
#                      'min': -4.3,
#                      'morn': -4.08,
#                      'night': -2.95},
#             'uvi': 1.77,
#             'weather': [{'description': '온흐림',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 312,
#             'wind_gust': 8.62,
#             'wind_speed': 4.19},
#            {'clouds': 100,
#             'dew_point': -19.88,
#             'dt': 1670209200,
#             'feels_like': {'day': -4.85,
#                            'eve': -5.81,
#                            'morn': -6.29,
#                            'night': -2.2},
#             'humidity': 22,
#             'moon_phase': 0.4,
#             'moonrise': 1670221260,
#             'moonset': 1670181720,
#             'pop': 0,
#             'pressure': 1030,
#             'sunrise': 1670192988,
#             'sunset': 1670228036,
#             'temp': {'day': -0.83,
#                      'eve': -1.82,
#                      'max': -0.14,
#                      'min': -3.15,
#                      'morn': -2.78,
#                      'night': -2.2},
#             'uvi': 1.97,
#             'weather': [{'description': '온흐림',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 312,
#             'wind_gust': 7.13,
#             'wind_speed': 4.28},
#            {'clouds': 29,
#             'dew_point': -5.49,
#             'dt': 1670295600,
#             'feels_like': {'day': -0.13,
#                            'eve': 1.8,
#                            'morn': -2.73,
#                            'night': 0.05},
#             'humidity': 57,
#             'moon_phase': 0.44,
#             'moonrise': 1670309460,
#             'moonset': 1670271960,
#             'pop': 0,
#             'pressure': 1026,
#             'sunrise': 1670279440,
#             'sunset': 1670314432,
#             'temp': {'day': 1.74,
#                      'eve': 1.8,
#                      'max': 3.33,
#                      'min': -2.79,
#                      'morn': -2.73,
#                      'night': 1.49},
#             'uvi': 2,
#             'weather': [{'description': '구름조금',
#                          'icon': '03d',
#                          'id': 802,
#                          'main': 'Clouds'}],
#             'wind_deg': 266,
#             'wind_gust': 5.12,
#             'wind_speed': 2.07},
#            {'clouds': 100,
#             'dew_point': -1.42,
#             'dt': 1670382000,
#             'feels_like': {'day': 2.22,
#                            'eve': 2.94,
#                            'morn': -1.52,
#                            'night': 2.1},
#             'humidity': 66,
#             'moon_phase': 0.47,
#             'moonrise': 1670397840,
#             'moonset': 1670362140,
#             'pop': 0.05,
#             'pressure': 1024,
#             'sunrise': 1670365891,
#             'sunset': 1670400831,
#             'temp': {'day': 4.02,
#                      'eve': 4.13,
#                      'max': 4.51,
#                      'min': 0.31,
#                      'morn': 0.31,
#                      'night': 3.73},
#             'uvi': 2,
#             'weather': [{'description': '온흐림',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 157,
#             'wind_gust': 4.6,
#             'wind_speed': 2.01},
#            {'clouds': 100,
#             'dew_point': 2.22,
#             'dt': 1670468400,
#             'feels_like': {'day': 4.61,
#                            'eve': -0.83,
#                            'morn': 3.68,
#                            'night': -2.92},
#             'humidity': 71,
#             'moon_phase': 0.5,
#             'moonrise': 1670486640,
#             'moonset': 1670452320,
#             'pop': 0.5,
#             'pressure': 1022,
#             'rain': 0.37,
#             'sunrise': 1670452342,
#             'sunset': 1670487231,
#             'temp': {'day': 6.72,
#                      'eve': 3.05,
#                      'max': 6.72,
#                      'min': 1.13,
#                      'morn': 3.68,
#                      'night': 1.13},
#             'uvi': 2,
#             'weather': [{'description': '실 비',
#                          'icon': '10d',
#                          'id': 500,
#                          'main': 'Rain'}],
#             'wind_deg': 309,
#             'wind_gust': 9.08,
#             'wind_speed': 5.15}],
#  'lat': 37.2217,
#  'lon': 127.1815,
#  'timezone': 'Asia/Seoul',
#  'timezone_offset': 32400}
# 20221202 맑음 -6.54 -4.56
# 20221203 맑음 -4.99 -2.33
# 20221204 눈 -1.85 -1.85
# 20221205 온흐림 -4.08 -2.95
# 20221206 온흐림 -2.78 -2.2
# 20221207 구름조금 -2.73 1.49
# 20221208 온흐림 0.31 3.73
# 20221209 실 비 3.68 1.13
